# %% [markdown]
# ### Generate metrics & Run evaluations (ROUGE, COSINE, LLM acting as a judge in the loop)
# ---
#
# In this notebook:
#
# 1. We will extract the titles generated as completions from the bedrock models (claude sonnet, llama, mistral), and load these into a CSV file
#
# 1. Generate metrics on accuracy ([ROUGE-L](https://en.wikipedia.org/wiki/ROUGE_(metric)) and [Cosine Similarity](https://en.wikipedia.org/wiki/Cosine_similarity) scores), performance, token throughput, inference, etc.
#
# 1. View all model completions to get a ***Vibe check*** on how each of the model performs. Next, have Claude Sonnet as a judge in the loop to go through each completion from multiple models, and decide which one best matches the human generated title. [Claude Sonnet](https://www.anthropic.com/claude) evaluates the most optimal model based on the [evaluation prompt](data/prompts/eval_template.txt) that is tuned into it. In this case, Sonnet acts as a judge to find the title that best captures the content of the meeting.

# %%
# import libraries
import os
import ray
import json
import yaml
import glob
import copy
import time
import boto3
import logging
import pandas as pd  
from numpy import dot
from pathlib import Path
from numpy.linalg import norm
from litellm import completion ## support for text generation models on bedrock
from rouge_score import rouge_scorer
from typing import Dict, Optional, List
from bedrock_utils import get_bedrock_client
# Out:
# 2024-06-01 17:14:07,514	INFO util.py:154 -- Outdated packages:
#   ipywidgets==7.6.5 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.

# %% [markdown]
# #### Set a logger

# %%
logging.basicConfig(format='[%(asctime)s] p%(process)s {%(filename)s:%(lineno)d} %(levelname)s - %(message)s', level=logging.INFO)
logger = logging.getLogger(__name__)

# %% [markdown]
# #### Initialize the Ray Server that is used to run Asynchronous inference

# %%
# initialize the ray service to run async calls in parallel to bedrock easily
if ray.is_initialized():
    ray.shutdown()
ray.init()
# Out:
# 2024-06-01 17:14:11,293	INFO worker.py:1749 -- Started a local Ray instance.
# RayContext(dashboard_url='', python_version='3.11.7', ray_version='2.11.0', ray_commit='2eb4a8119f903f79b78c01eaa9db06c6c390051c')

# %% [markdown]
# #### Load the config file: Contains model information, data directory information

# %%
## load the config file
# global constants
CONFIG_FILE_PATH = "config.yml"

# %%
# read the config yaml file
fpath = CONFIG_FILE_PATH
with open(fpath, 'r') as yaml_in:
    config = yaml.safe_load(yaml_in)
logger.info(f"config read from {fpath} -> {json.dumps(config, indent=2)}")
# Out:
# [2024-06-01 17:33:27,913] p163 {3034282685.py:5} INFO - config read from config.yml -> {
#   "app_name": "genai-chapterize-meeting-transcripts",
#   "aws": {
#     "region": "us-east-1"
#   },
#   "dir": {
#     "data": "data",
#     "raw": "data/source_data",
#     "processed": "data/processed_data",
#     "completions": "data/title_completions",
#     "model_eval_completions": "data/model_eval_completions",
#     "golden": "data/source_data/golden",
#     "prompts": "data/prompts",
#     "metrics": "data/metrics",
#     "processed_file": "processed.csv",
#     "chapterized_file": "chapterized.csv",
#     "metrics_file": "per_request_results.csv",
#     "summary_metrics_file": "summary_metrics.csv",
#     "model_evals_file": "model_eval.csv",
#     "processed_prompts_for_eval": "processed_evaluation_prompts.csv",
#     "filtered_titles_for_eval": "filtered_titles_for_eval.csv",
#     "final_report": "recommended_model.csv",
#     "model_distribution": "model_distribution_count.csv",
#     "overall_eval_report": "overall_evaluation_report.csv",
#     "file_type_to_process": "json"
#   },
#   "run_steps": {
#     "0_already_chapterized_data.ipynb": true,
#     "0_chapterize_data.ipynb": false,
#     "1_generate_chapter_titles.ipynb": true,
#     "2_summarize_metrics.ipynb": true
#   },
#   "inference_parameters_for_title_generation": {
#     "temperature": 0.1,
#     "caching": false
#   },
#   "inference_parameters_for_explanations": {
#     "temperature": 0.1,
#     "caching": false,
#     "max_tokens": 500
#   },
#   "title_generation_thresholds": {
#     "max_chapter_length": 20
#   },
#   "parallel_inference_count": 15,
#   "sleep_in_seconds_between_models": 5,
#   "response_prefix_to_remove": [
#     "Title:",
#     "<title>",
#     "</title>",
#     "Chapter: ",
#     "Sure! Here is a possible title for the chapter based on the provided text:"
#   ],
#   "response_suffix_to_clip": "[",
#   "experiments": [
#     {
#       "name": "chapterize-meeting-transcripts",
#       "prompt_template": null,
#       "model_list": [
#         {
#           "model": "meta.llama3-8b-instruct-v1:0",
#           "max_context_window": 4096,
#           "prompt_template": "llama3_template.txt",
#           "input_tokens_pricing": 0.0004,
#           "output_tokens_pricing": 0.0006
#         },
#         {
#           "model": "meta.llama3-70b-instruct-v1:0",
#           "max_context_window": 4096,
#           "prompt_template": "llama3_template.txt",
#           "input_tokens_pricing": 0.00265,
#           "output_tokens_pricing": 0.0035
#         },
#         {
#           "model": "mistral.mixtral-8x7b-instruct-v0:1",
#           "prompt_template": "mistral_template.txt",
#           "max_context_window": 32000,
#           "input_tokens_pricing": 0.00045,
#           "output_tokens_pricing": 0.0007
#         },
#         {
#           "model": "mistral.mistral-7b-instruct-v0:2",
#           "prompt_template": "mistral_template.txt",
#           "max_context_window": 32000,
#           "input_tokens_pricing": 0.00015,
#           "output_tokens_pricing": 0.0002
#         },
#         {
#           "model": "anthropic.claude-3-haiku-20240307-v1:0",
#           "prompt_template": "anthropic_template.txt",
#           "max_context_window": 200000,
#           "input_tokens_pricing": 0.00025,
#           "output_tokens_pricing": 0.00125
#         },
#         {
#           "model": "anthropic.claude-3-sonnet-20240229-v1:0",
#           "max_context_window": 200000,
#           "prompt_template": "anthropic_template.txt",
#           "input_tokens_pricing": 0.003,
#           "output_tokens_pricing": 0.015
#         },
#         {
#           "model": "amazon.titan-text-express-v1",
#           "max_context_window": 8000,
#           "prompt_template": "titan_template.txt",
#           "input_tokens_pricing": 0.0008,
#           "output_tokens_pricing": 0.0016
#         }
#       ]
#     }
#   ],
#   "eval_model_info": {
#     "model": "anthropic.claude-3-sonnet-20240229-v1:0",
#     "prompt_template": "eval_template.txt",
#     "input_tokens_pricing": 0.003,
#     "output_tokens_pricing": 0.015
#   },
#   "embeddings_model_info": {
#     "model": "amazon.titan-embed-text-v1",
#     "max_text_len_for_embedding": 500,
#     "rouge_metric_selection": "rougeL"
#   },
#   "report": {
#     "summary_text": "The average inference latency for this workload with prompt tokens {avg_prompt_token_count} (p95 is {p95_prompt_token_count}) and completion tokens {avg_completion_token_count} (p95 is {p95_completion_token_count}) when using {model_id} is {avg_latency}s (p95 is {p95_latency}s) and the average cost for 10,000 requests is ${avg_cost} (p95 is ${p95_cost_per_txn}). The mean ROUGE-L score is {mean_rouge_l_score} and Cosine Similarity is {mean_cosine_similarity_score}. This is based on {count} requests.",
#     "model_recommendation": "The recommended model with the best match title based on an evaluation of {count} titles is {model_id}, with a {percentage_of_occurrence}% selection rate. The total cost to run the LLM as a judge evaluation is ${total_evaluation_cost}.",
#     "eval_report_explanation": "The mean ROUGE-L score is {rouge_score}, mean Cosine Similarity is {cosine_score} and the LLM as a judge pick rate is {llm_as_a_judge}."
#   }
# }

# %%
## Represents extracted all metric files
fpath = os.path.join(config['dir']['completions'], "**", "*", "*.json")
metric_files = glob.glob(fpath, recursive=True)
logger.info(f"there are {len(metric_files)} files in {fpath}")
# Out:
# [2024-06-01 17:14:12,372] p163 {3931314738.py:4} INFO - there are 62 files in data/title_completions/**/*/*.json

# %% [markdown]
# #### Generate a simple CSV with metrics on title completions, chapters, and performance latency
# ---
#
# 1. This section of the notebook calculates metrics like title completions from each model in the config file for respective chapters, latency.
#
# 1. The CSV also contains the original title that was given as a human generated title in the original data frame if any. If the human generated title is not provided, the data frame will not have it.

# %%
metrics = []
for f in metric_files:
    metrics.append(json.loads(Path(f).read_text()))
df = pd.DataFrame(metrics)
df = df.drop(columns=['exception', 'prompt'])
df = df.sort_values(by=['file_name', 'model_id', 'chapter_id'])
df = df.rename(columns={'completion': 'chapter_title', 'time_taken_in_seconds': 'latency_seconds'})
logger.info(f"all metrics data is read into a dataframe of shape {df.shape}")
count = df.shape[0]
# Out:
# [2024-06-01 17:14:12,400] p163 {3027428405.py:8} INFO - all metrics data is read into a dataframe of shape (62, 11)

# %%
df.head(20)
# Out:
#                                    chapter_title  \
# 31              Higgs Boson and its Implications
# 30                    Particle Physics Prospects
# 33                     Exploring Quantum Gravity
# 32                             Higher Dimensions
# 35            Exploring the Frontiers of Reality
# 34  Antimatter in Medicine and Space Exploration
# 19              Higgs Boson Particle Discoveries
# 18                    Particle Physics Frontiers
# 21                      Quantum Gravity Theories
# 20            Multidimensional Universe Theories
# 23            Probing Particle Physics Frontiers
# 22             Antimatter's Scientific Potential
# 13                        Higgs Boson Discussion
# 12                    Future of Particle Physics
# 15                    Quantum Gravity Discussion
# 14                  Dimensions Beyond Space-Time
# 17                   Probing Fundamental Physics
# 16                       Antimatter Applications
# 7                       Higgs Boson Implications
# 6                              Future of Physics
#
#                         file_name  chapter_id  \
# 31  particle_physics_meeting.json           0
# 30  particle_physics_meeting.json           1
# 33  particle_physics_meeting.json           2
# 32  particle_physics_meeting.json           3
# 35  particle_physics_meeting.json           4
# 34  particle_physics_meeting.json           5
# 19  particle_physics_meeting.json           0
# 18  particle_physics_meeting.json           1
# 21  particle_physics_meeting.json           2
# 20  particle_physics_meeting.json           3
# 23  particle_physics_meeting.json           4
# 22  particle_physics_meeting.json           5
# 13  particle_physics_meeting.json           0
# 12  particle_physics_meeting.json           1
# 15  particle_physics_meeting.json           2
# 14  particle_physics_meeting.json           3
# 17  particle_physics_meeting.json           4
# 16  particle_physics_meeting.json           5
# 7   particle_physics_meeting.json           0
# 6   particle_physics_meeting.json           1
#
#                                    model_id  latency_seconds  \
# 31             amazon.titan-text-express-v1         0.959070
# 30             amazon.titan-text-express-v1         0.875003
# 33             amazon.titan-text-express-v1         1.146632
# 32             amazon.titan-text-express-v1         1.135567
# 35             amazon.titan-text-express-v1         1.225493
# 34             amazon.titan-text-express-v1         1.360492
# 19   anthropic.claude-3-haiku-20240307-v1:0         0.729197
# 18   anthropic.claude-3-haiku-20240307-v1:0         0.553375
# 21   anthropic.claude-3-haiku-20240307-v1:0         0.753200
# 20   anthropic.claude-3-haiku-20240307-v1:0         0.802009
# 23   anthropic.claude-3-haiku-20240307-v1:0         0.758959
# 22   anthropic.claude-3-haiku-20240307-v1:0         0.738477
# 13  anthropic.claude-3-sonnet-20240229-v1:0         0.711374
# 12  anthropic.claude-3-sonnet-20240229-v1:0         0.877177
# 15  anthropic.claude-3-sonnet-20240229-v1:0         0.910392
# 14  anthropic.claude-3-sonnet-20240229-v1:0         0.918277
# 17  anthropic.claude-3-sonnet-20240229-v1:0         1.551325
# 16  anthropic.claude-3-sonnet-20240229-v1:0         0.570935
# 7             meta.llama3-70b-instruct-v1:0         0.858110
# 6             meta.llama3-70b-instruct-v1:0         1.129430
#
#     completion_token_count  prompt_token_count  input_token_price  \
# 31                      10                 341           0.000273
# 30                       6                 330           0.000264
# 33                       6                 343           0.000274
# 32                       4                 330           0.000264
# 35                       9                 298           0.000238
# 34                      10                 296           0.000237
# 19                      13                 387           0.000097
# 18                       9                 373           0.000093
# 21                       9                 385           0.000096
# 20                      11                 375           0.000094
# 23                      12                 336           0.000084
# 22                      10                 336           0.000084
# 13                      10                 387           0.001161
# 12                       8                 373           0.001119
# 15                       8                 385           0.001155
# 14                       9                 375           0.001125
# 17                       9                 336           0.001008
# 16                       7                 336           0.001008
# 7                        9                 365           0.000967
# 6                        6                 354           0.000938
#
#     output_token_pricing                                       chapter_text  \
# 31              0.000016  1 "Dr. E" (1234567890)\n00:00:00.000 --> 00:00...
# 30              0.000010  996 "Dr. M" (2345678901)\n10:02:15.340 --> 10:...
# 33              0.000010  1001 "Dr. S" (3456789012)\n10:02:42.520 --> 10...
# 32              0.000006  1006 "Dr. D" (4567890123)\n10:03:13.400 --> 10...
# 35              0.000014  1011 "Dr. E" (1234567890)\n10:03:44.900 --> 10...
# 34              0.000016  1015 "Dr. E" (1234567890)\n10:04:10.100 --> 10...
# 19              0.000016  1 "Dr. E" (1234567890)\n00:00:00.000 --> 00:00...
# 18              0.000011  996 "Dr. M" (2345678901)\n10:02:15.340 --> 10:...
# 21              0.000011  1001 "Dr. S" (3456789012)\n10:02:42.520 --> 10...
# 20              0.000014  1006 "Dr. D" (4567890123)\n10:03:13.400 --> 10...
# 23              0.000015  1011 "Dr. E" (1234567890)\n10:03:44.900 --> 10...
# 22              0.000013  1015 "Dr. E" (1234567890)\n10:04:10.100 --> 10...
# 13              0.000150  1 "Dr. E" (1234567890)\n00:00:00.000 --> 00:00...
# 12              0.000120  996 "Dr. M" (2345678901)\n10:02:15.340 --> 10:...
# 15              0.000120  1001 "Dr. S" (3456789012)\n10:02:42.520 --> 10...
# 14              0.000135  1006 "Dr. D" (4567890123)\n10:03:13.400 --> 10...
# 17              0.000135  1011 "Dr. E" (1234567890)\n10:03:44.900 --> 10...
# 16              0.000105  1015 "Dr. E" (1234567890)\n10:04:10.100 --> 10...
# 7               0.000031  1 "Dr. E" (1234567890)\n00:00:00.000 --> 00:00...
# 6               0.000021  996 "Dr. M" (2345678901)\n10:02:15.340 --> 10:...
#
#                                        original_title
# 31    Discussing the Higgs Boson and Its Implications
# 30     Exploring Future Frontiers in Particle Physics
# 33          The Quest for a Theory of Quantum Gravity
# 32  Exploring Higher Dimensions and the Fabric of ...
# 35  The Role of Theory and Experimentation in Physics
# 34          Antimatter and Its Potential Applications
# 19    Discussing the Higgs Boson and Its Implications
# 18     Exploring Future Frontiers in Particle Physics
# 21          The Quest for a Theory of Quantum Gravity
# 20  Exploring Higher Dimensions and the Fabric of ...
# 23  The Role of Theory and Experimentation in Physics
# 22          Antimatter and Its Potential Applications
# 13    Discussing the Higgs Boson and Its Implications
# 12     Exploring Future Frontiers in Particle Physics
# 15          The Quest for a Theory of Quantum Gravity
# 14  Exploring Higher Dimensions and the Fabric of ...
# 17  The Role of Theory and Experimentation in Physics
# 16          Antimatter and Its Potential Applications
# 7     Discussing the Higgs Boson and Its Implications
# 6      Exploring Future Frontiers in Particle Physics

# %% [markdown]
# #### Calculate Cosine versus ROUGE metrics for generated chapter titles

# %%
def sanitize_title(title):
    """
    This function sanitizes the chapter titles that are generated. To add elements you want to remove from the chapter titles, modify the 
    'response_prefix_to_remove' in the config file
    """
    if title is None:
        return title
    suffixes_to_remove: List[str] = config['response_prefix_to_remove']
    for response_to_remove in suffixes_to_remove:
        title = title.replace(response_to_remove, "")
    title = title.strip()
    title = title.split("\n")[0]
    return title
df.chapter_title = df.chapter_title.map(sanitize_title)
# view information about the type of data generated by the models, and other metrics below
df.head(10)
# Out:
#                                    chapter_title  \
# 31              Higgs Boson and its Implications
# 30                    Particle Physics Prospects
# 33                     Exploring Quantum Gravity
# 32                             Higher Dimensions
# 35            Exploring the Frontiers of Reality
# 34  Antimatter in Medicine and Space Exploration
# 19              Higgs Boson Particle Discoveries
# 18                    Particle Physics Frontiers
# 21                      Quantum Gravity Theories
# 20            Multidimensional Universe Theories
#
#                         file_name  chapter_id  \
# 31  particle_physics_meeting.json           0
# 30  particle_physics_meeting.json           1
# 33  particle_physics_meeting.json           2
# 32  particle_physics_meeting.json           3
# 35  particle_physics_meeting.json           4
# 34  particle_physics_meeting.json           5
# 19  particle_physics_meeting.json           0
# 18  particle_physics_meeting.json           1
# 21  particle_physics_meeting.json           2
# 20  particle_physics_meeting.json           3
#
#                                   model_id  latency_seconds  \
# 31            amazon.titan-text-express-v1         0.959070
# 30            amazon.titan-text-express-v1         0.875003
# 33            amazon.titan-text-express-v1         1.146632
# 32            amazon.titan-text-express-v1         1.135567
# 35            amazon.titan-text-express-v1         1.225493
# 34            amazon.titan-text-express-v1         1.360492
# 19  anthropic.claude-3-haiku-20240307-v1:0         0.729197
# 18  anthropic.claude-3-haiku-20240307-v1:0         0.553375
# 21  anthropic.claude-3-haiku-20240307-v1:0         0.753200
# 20  anthropic.claude-3-haiku-20240307-v1:0         0.802009
#
#     completion_token_count  prompt_token_count  input_token_price  \
# 31                      10                 341           0.000273
# 30                       6                 330           0.000264
# 33                       6                 343           0.000274
# 32                       4                 330           0.000264
# 35                       9                 298           0.000238
# 34                      10                 296           0.000237
# 19                      13                 387           0.000097
# 18                       9                 373           0.000093
# 21                       9                 385           0.000096
# 20                      11                 375           0.000094
#
#     output_token_pricing                                       chapter_text  \
# 31              0.000016  1 "Dr. E" (1234567890)\n00:00:00.000 --> 00:00...
# 30              0.000010  996 "Dr. M" (2345678901)\n10:02:15.340 --> 10:...
# 33              0.000010  1001 "Dr. S" (3456789012)\n10:02:42.520 --> 10...
# 32              0.000006  1006 "Dr. D" (4567890123)\n10:03:13.400 --> 10...
# 35              0.000014  1011 "Dr. E" (1234567890)\n10:03:44.900 --> 10...
# 34              0.000016  1015 "Dr. E" (1234567890)\n10:04:10.100 --> 10...
# 19              0.000016  1 "Dr. E" (1234567890)\n00:00:00.000 --> 00:00...
# 18              0.000011  996 "Dr. M" (2345678901)\n10:02:15.340 --> 10:...
# 21              0.000011  1001 "Dr. S" (3456789012)\n10:02:42.520 --> 10...
# 20              0.000014  1006 "Dr. D" (4567890123)\n10:03:13.400 --> 10...
#
#                                        original_title
# 31    Discussing the Higgs Boson and Its Implications
# 30     Exploring Future Frontiers in Particle Physics
# 33          The Quest for a Theory of Quantum Gravity
# 32  Exploring Higher Dimensions and the Fabric of ...
# 35  The Role of Theory and Experimentation in Physics
# 34          Antimatter and Its Potential Applications
# 19    Discussing the Higgs Boson and Its Implications
# 18     Exploring Future Frontiers in Particle Physics
# 21          The Quest for a Theory of Quantum Gravity
# 20  Exploring Higher Dimensions and the Fabric of ...

# %% [markdown]
# #### ROUGE & Cosine Similarity Scores for titles:
# ---
#
# Here, the `amazon.titan-embed-text-v1` is used to get the embeddings of texts. To use a different embeddings model, change the `model` in the `embeddings_model_info` and modify this function.

# %%
from typing import Optional
MAX_TEXT_LEN_FOR_EMBEDDING: int = config['embeddings_model_info']['max_text_len_for_embedding']
bedrock: Optional[get_bedrock_client] = None

def get_embedding(text: str, modelId: str=config['embeddings_model_info'].get('model'), accept: str='application/json', contentType: str='application/json'):
    """
    Generates embeddings for the chapter titles and original titles to generate cosine similarity measures
    """
    global bedrock
    if bedrock is None:
        bedrock = get_bedrock_client()
    body = json.dumps({"inputText": text[:MAX_TEXT_LEN_FOR_EMBEDDING]})
    response = bedrock.invoke_model(body=body, modelId=modelId, accept=accept, contentType=contentType)
    response_body = json.loads(response.get('body').read())
    embedding = response_body.get('embedding')
    token_count = response_body.get('inputTextTokenCount')
    return embedding, token_count

def get_cosine_similarity(text1: str, text2: str) -> float:
    """
    This function calculates the cosine similarity between the chapter title generated from models, and the human generated title (if any)
    """
    A,_ = get_embedding(text1)
    B,_ = get_embedding(text2)
    cosine = dot(A, B)/(norm(A)*norm(B))
    return cosine

def get_rouge_l_score(completion: str, golden: str) -> float:
    """
    This function calculates the rouge-l score between the chapter title generated from models, and the human generated title (if any)
    """
    rouge_metric_selection: str = config['embeddings_model_info']['rouge_metric_selection']
    scorer = rouge_scorer.RougeScorer([rouge_metric_selection])
    scores = scorer.score(golden, completion)
    return round(scores[rouge_metric_selection].fmeasure, 4)

# %%
def compare_titles(row):
    """
    Generates the rouge and cosine similarity scores for chapter titles and original titles
    """
    if (row.get('original_title') and row.get('chapter_title') is not None) and (pd.notna(row.get('original_title')) and pd.notna(row.get('chapter_title'))):
        logger.info(f"Chapter title: {row['chapter_title']}, Original title: {row['original_title']}")
        rouge_l_score = get_rouge_l_score(row['chapter_title'], row['original_title'])
        cosine_sim = get_cosine_similarity(row['chapter_title'].lower(), row['original_title'].lower())
        return pd.Series([rouge_l_score, cosine_sim])
    else:
        logger.info(f'ROUGE scores and Cosine similarity scores cannot be computed since original titles are not provided in the chapterized dataset')
        rouge_l_score, cosine_sim = None, None

if 'original_title' in df.columns:
    df[['rouge_l_f1_score', 'cosine_similarity']] = df.apply(compare_titles, axis=1)
else:
    logger.info(f"No evaluation metrics available since Golden titles are not provided in the dataset.")
# Out:
# [2024-06-01 17:14:12,444] p163 {96059692.py:6} INFO - Chapter title: Higgs Boson and its Implications, Original title: Discussing the Higgs Boson and Its Implications
# [2024-06-01 17:14:12,444] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:12,452] p163 {credentials.py:1278} INFO - Found credentials in shared credentials file: ~/.aws/credentials
# Create new client
#   Using region: None
# boto3 Bedrock client successfully created!
# bedrock-runtime(https://bedrock-runtime.us-east-1.amazonaws.com)
# [2024-06-01 17:14:13,516] p163 {96059692.py:6} INFO - Chapter title: Particle Physics Prospects, Original title: Exploring Future Frontiers in Particle Physics
# [2024-06-01 17:14:13,516] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:14,063] p163 {96059692.py:6} INFO - Chapter title: Exploring Quantum Gravity, Original title: The Quest for a Theory of Quantum Gravity
# [2024-06-01 17:14:14,064] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:14,927] p163 {96059692.py:6} INFO - Chapter title: Higher Dimensions, Original title: Exploring Higher Dimensions and the Fabric of Reality
# [2024-06-01 17:14:14,928] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:15,463] p163 {96059692.py:6} INFO - Chapter title: Exploring the Frontiers of Reality, Original title: The Role of Theory and Experimentation in Physics
# [2024-06-01 17:14:15,465] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:16,264] p163 {96059692.py:6} INFO - Chapter title: Antimatter in Medicine and Space Exploration, Original title: Antimatter and Its Potential Applications
# [2024-06-01 17:14:16,265] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:16,501] p163 {96059692.py:6} INFO - Chapter title: Higgs Boson Particle Discoveries, Original title: Discussing the Higgs Boson and Its Implications
# [2024-06-01 17:14:16,502] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:17,443] p163 {96059692.py:6} INFO - Chapter title: Particle Physics Frontiers, Original title: Exploring Future Frontiers in Particle Physics
# [2024-06-01 17:14:17,444] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:18,002] p163 {96059692.py:6} INFO - Chapter title: Quantum Gravity Theories, Original title: The Quest for a Theory of Quantum Gravity
# [2024-06-01 17:14:18,003] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:18,903] p163 {96059692.py:6} INFO - Chapter title: Multidimensional Universe Theories, Original title: Exploring Higher Dimensions and the Fabric of Reality
# [2024-06-01 17:14:18,907] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:19,460] p163 {96059692.py:6} INFO - Chapter title: Probing Particle Physics Frontiers, Original title: The Role of Theory and Experimentation in Physics
# [2024-06-01 17:14:19,461] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:20,011] p163 {96059692.py:6} INFO - Chapter title: Antimatter's Scientific Potential, Original title: Antimatter and Its Potential Applications
# [2024-06-01 17:14:20,012] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:20,576] p163 {96059692.py:6} INFO - Chapter title: Higgs Boson Discussion, Original title: Discussing the Higgs Boson and Its Implications
# [2024-06-01 17:14:20,577] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:21,138] p163 {96059692.py:6} INFO - Chapter title: Future of Particle Physics, Original title: Exploring Future Frontiers in Particle Physics
# [2024-06-01 17:14:21,139] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:21,982] p163 {96059692.py:6} INFO - Chapter title: Quantum Gravity Discussion, Original title: The Quest for a Theory of Quantum Gravity
# [2024-06-01 17:14:21,982] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:22,483] p163 {96059692.py:6} INFO - Chapter title: Dimensions Beyond Space-Time, Original title: Exploring Higher Dimensions and the Fabric of Reality
# [2024-06-01 17:14:22,484] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:23,005] p163 {96059692.py:6} INFO - Chapter title: Probing Fundamental Physics, Original title: The Role of Theory and Experimentation in Physics
# [2024-06-01 17:14:23,005] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:23,192] p163 {96059692.py:6} INFO - Chapter title: Antimatter Applications, Original title: Antimatter and Its Potential Applications
# [2024-06-01 17:14:23,192] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:23,703] p163 {96059692.py:6} INFO - Chapter title: Higgs Boson Implications, Original title: Discussing the Higgs Boson and Its Implications
# [2024-06-01 17:14:23,703] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:24,276] p163 {96059692.py:6} INFO - Chapter title: Future of Physics, Original title: Exploring Future Frontiers in Particle Physics
# [2024-06-01 17:14:24,276] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:24,872] p163 {96059692.py:6} INFO - Chapter title: Quantum Gravity Implications, Original title: The Quest for a Theory of Quantum Gravity
# [2024-06-01 17:14:24,873] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:25,769] p163 {96059692.py:6} INFO - Chapter title: Higher Dimensions, Original title: Exploring Higher Dimensions and the Fabric of Reality
# [2024-06-01 17:14:25,770] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:26,328] p163 {96059692.py:6} INFO - Chapter title: Probing Reality's Fabric, Original title: The Role of Theory and Experimentation in Physics
# [2024-06-01 17:14:26,329] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:27,226] p163 {96059692.py:6} INFO - Chapter title: Antimatter Applications, Original title: Antimatter and Its Potential Applications
# [2024-06-01 17:14:27,227] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:27,783] p163 {96059692.py:6} INFO - Chapter title: Higgs Boson Discussion, Original title: Discussing the Higgs Boson and Its Implications
# [2024-06-01 17:14:27,783] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:28,595] p163 {96059692.py:6} INFO - Chapter title: Future of Particle Physics, Original title: Exploring Future Frontiers in Particle Physics
# [2024-06-01 17:14:28,597] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:29,451] p163 {96059692.py:6} INFO - Chapter title: Quantum Gravity Implications, Original title: The Quest for a Theory of Quantum Gravity
# [2024-06-01 17:14:29,452] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:29,644] p163 {96059692.py:6} INFO - Chapter title: Higher Dimensions, Original title: Exploring Higher Dimensions and the Fabric of Reality
# [2024-06-01 17:14:29,645] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:30,122] p163 {96059692.py:6} INFO - Chapter title: Particle Accelerators, Original title: The Role of Theory and Experimentation in Physics
# [2024-06-01 17:14:30,123] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:31,029] p163 {96059692.py:6} INFO - Chapter title: Antimatter Applications, Original title: Antimatter and Its Potential Applications
# [2024-06-01 17:14:31,029] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:31,933] p163 {96059692.py:6} INFO - Chapter title: Higgs Applications, Original title: Discussing the Higgs Boson and Its Implications
# [2024-06-01 17:14:31,934] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:32,467] p163 {96059692.py:6} INFO - Chapter title: Future Physics Projects, Original title: Exploring Future Frontiers in Particle Physics
# [2024-06-01 17:14:32,467] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:33,019] p163 {96059692.py:6} INFO - Chapter title: Quantum Gravity Discussions, Original title: The Quest for a Theory of Quantum Gravity
# [2024-06-01 17:14:33,020] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:33,572] p163 {96059692.py:6} INFO - Chapter title: Higher Dimensions Debate, Original title: Exploring Higher Dimensions and the Fabric of Reality
# [2024-06-01 17:14:33,573] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:34,094] p163 {96059692.py:6} INFO - Chapter title: New Insights, Original title: The Role of Theory and Experimentation in Physics
# [2024-06-01 17:14:34,094] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:34,664] p163 {96059692.py:6} INFO - Chapter title: Antimatter Applications, Original title: Antimatter and Its Potential Applications
# [2024-06-01 17:14:34,665] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:35,190] p163 {96059692.py:6} INFO - Chapter title: Higgs Boson Discussion, Original title: Discussing the Higgs Boson and Its Implications
# [2024-06-01 17:14:35,191] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:35,767] p163 {96059692.py:6} INFO - Chapter title: Future of Particle Physics, Original title: Exploring Future Frontiers in Particle Physics
# [2024-06-01 17:14:35,768] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:35,938] p163 {96059692.py:6} INFO - Chapter title: Quantum Gravity Theories, Original title: The Quest for a Theory of Quantum Gravity
# [2024-06-01 17:14:35,940] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:36,504] p163 {96059692.py:6} INFO - Chapter title: Higher Dimensions, Original title: Exploring Higher Dimensions and the Fabric of Reality
# [2024-06-01 17:14:36,506] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:36,715] p163 {96059692.py:6} INFO - Chapter title: Exploring Reality, Original title: The Role of Theory and Experimentation in Physics
# [2024-06-01 17:14:36,716] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:36,897] p163 {96059692.py:6} INFO - Chapter title: Antimatter Applications, Original title: Antimatter and Its Potential Applications
# [2024-06-01 17:14:36,897] p163 {rouge_scorer.py:83} INFO - Using default tokenizer.
# [2024-06-01 17:14:37,479] p163 {96059692.py:11} INFO - ROUGE scores and Cosine similarity scores cannot be computed since original titles are not provided in the chapterized dataset
# [2024-06-01 17:14:37,481] p163 {96059692.py:11} INFO - ROUGE scores and Cosine similarity scores cannot be computed since original titles are not provided in the chapterized dataset
# [2024-06-01 17:14:37,482] p163 {96059692.py:11} INFO - ROUGE scores and Cosine similarity scores cannot be computed since original titles are not provided in the chapterized dataset
# [2024-06-01 17:14:37,482] p163 {96059692.py:11} INFO - ROUGE scores and Cosine similarity scores cannot be computed since original titles are not provided in the chapterized dataset
# [2024-06-01 17:14:37,483] p163 {96059692.py:11} INFO - ROUGE scores and Cosine similarity scores cannot be computed since original titles are not provided in the chapterized dataset
# [2024-06-01 17:14:37,484] p163 {96059692.py:11} INFO - ROUGE scores and Cosine similarity scores cannot be computed since original titles are not provided in the chapterized dataset
# [2024-06-01 17:14:37,484] p163 {96059692.py:11} INFO - ROUGE scores and Cosine similarity scores cannot be computed since original titles are not provided in the chapterized dataset
# [2024-06-01 17:14:37,485] p163 {96059692.py:11} INFO - ROUGE scores and Cosine similarity scores cannot be computed since original titles are not provided in the chapterized dataset
# [2024-06-01 17:14:37,485] p163 {96059692.py:11} INFO - ROUGE scores and Cosine similarity scores cannot be computed since original titles are not provided in the chapterized dataset
# [2024-06-01 17:14:37,485] p163 {96059692.py:11} INFO - ROUGE scores and Cosine similarity scores cannot be computed since original titles are not provided in the chapterized dataset
# [2024-06-01 17:14:37,485] p163 {96059692.py:11} INFO - ROUGE scores and Cosine similarity scores cannot be computed since original titles are not provided in the chapterized dataset
# [2024-06-01 17:14:37,486] p163 {96059692.py:11} INFO - ROUGE scores and Cosine similarity scores cannot be computed since original titles are not provided in the chapterized dataset
# [2024-06-01 17:14:37,486] p163 {96059692.py:11} INFO - ROUGE scores and Cosine similarity scores cannot be computed since original titles are not provided in the chapterized dataset
# [2024-06-01 17:14:37,487] p163 {96059692.py:11} INFO - ROUGE scores and Cosine similarity scores cannot be computed since original titles are not provided in the chapterized dataset
# [2024-06-01 17:14:37,487] p163 {96059692.py:11} INFO - ROUGE scores and Cosine similarity scores cannot be computed since original titles are not provided in the chapterized dataset
# [2024-06-01 17:14:37,487] p163 {96059692.py:11} INFO - ROUGE scores and Cosine similarity scores cannot be computed since original titles are not provided in the chapterized dataset
# [2024-06-01 17:14:37,488] p163 {96059692.py:11} INFO - ROUGE scores and Cosine similarity scores cannot be computed since original titles are not provided in the chapterized dataset
# [2024-06-01 17:14:37,488] p163 {96059692.py:11} INFO - ROUGE scores and Cosine similarity scores cannot be computed since original titles are not provided in the chapterized dataset
# [2024-06-01 17:14:37,488] p163 {96059692.py:11} INFO - ROUGE scores and Cosine similarity scores cannot be computed since original titles are not provided in the chapterized dataset
# [2024-06-01 17:14:37,489] p163 {96059692.py:11} INFO - ROUGE scores and Cosine similarity scores cannot be computed since original titles are not provided in the chapterized dataset

# %%
# show the number of chapter titles generated by each of the model
df_per_model_id_counts = df['model_id'].value_counts()
df_per_model_id_counts
# Out:
# model_id
# amazon.titan-text-express-v1               10
# anthropic.claude-3-haiku-20240307-v1:0     10
# anthropic.claude-3-sonnet-20240229-v1:0    10
# mistral.mistral-7b-instruct-v0:2           10
# meta.llama3-70b-instruct-v1:0               6
# meta.llama3-8b-instruct-v1:0                6
# mistral.mixtral-8x7b-instruct-v0:1          6
# meta.llama2-13b-chat-v1                     4
# Name: count, dtype: int64

# %%
df.head(30)
# Out:
#                                    chapter_title  \
# 31              Higgs Boson and its Implications
# 30                    Particle Physics Prospects
# 33                     Exploring Quantum Gravity
# 32                             Higher Dimensions
# 35            Exploring the Frontiers of Reality
# 34  Antimatter in Medicine and Space Exploration
# 19              Higgs Boson Particle Discoveries
# 18                    Particle Physics Frontiers
# 21                      Quantum Gravity Theories
# 20            Multidimensional Universe Theories
# 23            Probing Particle Physics Frontiers
# 22             Antimatter's Scientific Potential
# 13                        Higgs Boson Discussion
# 12                    Future of Particle Physics
# 15                    Quantum Gravity Discussion
# 14                  Dimensions Beyond Space-Time
# 17                   Probing Fundamental Physics
# 16                       Antimatter Applications
# 7                       Higgs Boson Implications
# 6                              Future of Physics
# 9                   Quantum Gravity Implications
# 8                              Higher Dimensions
# 11                      Probing Reality's Fabric
# 10                       Antimatter Applications
# 1                         Higgs Boson Discussion
# 0                     Future of Particle Physics
# 3                   Quantum Gravity Implications
# 2                              Higher Dimensions
# 5                          Particle Accelerators
# 4                        Antimatter Applications
#
#                         file_name  chapter_id  \
# 31  particle_physics_meeting.json           0
# 30  particle_physics_meeting.json           1
# 33  particle_physics_meeting.json           2
# 32  particle_physics_meeting.json           3
# 35  particle_physics_meeting.json           4
# 34  particle_physics_meeting.json           5
# 19  particle_physics_meeting.json           0
# 18  particle_physics_meeting.json           1
# 21  particle_physics_meeting.json           2
# 20  particle_physics_meeting.json           3
# 23  particle_physics_meeting.json           4
# 22  particle_physics_meeting.json           5
# 13  particle_physics_meeting.json           0
# 12  particle_physics_meeting.json           1
# 15  particle_physics_meeting.json           2
# 14  particle_physics_meeting.json           3
# 17  particle_physics_meeting.json           4
# 16  particle_physics_meeting.json           5
# 7   particle_physics_meeting.json           0
# 6   particle_physics_meeting.json           1
# 9   particle_physics_meeting.json           2
# 8   particle_physics_meeting.json           3
# 11  particle_physics_meeting.json           4
# 10  particle_physics_meeting.json           5
# 1   particle_physics_meeting.json           0
# 0   particle_physics_meeting.json           1
# 3   particle_physics_meeting.json           2
# 2   particle_physics_meeting.json           3
# 5   particle_physics_meeting.json           4
# 4   particle_physics_meeting.json           5
#
#                                    model_id  latency_seconds  \
# 31             amazon.titan-text-express-v1         0.959070
# 30             amazon.titan-text-express-v1         0.875003
# 33             amazon.titan-text-express-v1         1.146632
# 32             amazon.titan-text-express-v1         1.135567
# 35             amazon.titan-text-express-v1         1.225493
# 34             amazon.titan-text-express-v1         1.360492
# 19   anthropic.claude-3-haiku-20240307-v1:0         0.729197
# 18   anthropic.claude-3-haiku-20240307-v1:0         0.553375
# 21   anthropic.claude-3-haiku-20240307-v1:0         0.753200
# 20   anthropic.claude-3-haiku-20240307-v1:0         0.802009
# 23   anthropic.claude-3-haiku-20240307-v1:0         0.758959
# 22   anthropic.claude-3-haiku-20240307-v1:0         0.738477
# 13  anthropic.claude-3-sonnet-20240229-v1:0         0.711374
# 12  anthropic.claude-3-sonnet-20240229-v1:0         0.877177
# 15  anthropic.claude-3-sonnet-20240229-v1:0         0.910392
# 14  anthropic.claude-3-sonnet-20240229-v1:0         0.918277
# 17  anthropic.claude-3-sonnet-20240229-v1:0         1.551325
# 16  anthropic.claude-3-sonnet-20240229-v1:0         0.570935
# 7             meta.llama3-70b-instruct-v1:0         0.858110
# 6             meta.llama3-70b-instruct-v1:0         1.129430
# 9             meta.llama3-70b-instruct-v1:0         1.069774
# 8             meta.llama3-70b-instruct-v1:0         0.808427
# 11            meta.llama3-70b-instruct-v1:0         0.854821
# 10            meta.llama3-70b-instruct-v1:0         1.065752
# 1              meta.llama3-8b-instruct-v1:0         0.745705
# 0              meta.llama3-8b-instruct-v1:0         0.766376
# 3              meta.llama3-8b-instruct-v1:0         0.762923
# 2              meta.llama3-8b-instruct-v1:0         0.746886
# 5              meta.llama3-8b-instruct-v1:0         0.766120
# 4              meta.llama3-8b-instruct-v1:0         0.739493
#
#     completion_token_count  prompt_token_count  input_token_price  \
# 31                      10                 341           0.000273
# 30                       6                 330           0.000264
# 33                       6                 343           0.000274
# 32                       4                 330           0.000264
# 35                       9                 298           0.000238
# 34                      10                 296           0.000237
# 19                      13                 387           0.000097
# 18                       9                 373           0.000093
# 21                       9                 385           0.000096
# 20                      11                 375           0.000094
# 23                      12                 336           0.000084
# 22                      10                 336           0.000084
# 13                      10                 387           0.001161
# 12                       8                 373           0.001119
# 15                       8                 385           0.001155
# 14                       9                 375           0.001125
# 17                       9                 336           0.001008
# 16                       7                 336           0.001008
# 7                        9                 365           0.000967
# 6                        6                 354           0.000938
# 9                        7                 367           0.000973
# 8                        5                 354           0.000938
# 11                       8                 322           0.000853
# 10                       7                 320           0.000848
# 1                        8                 365           0.000146
# 0                        7                 354           0.000142
# 3                        7                 367           0.000147
# 2                        5                 354           0.000142
# 5                        6                 322           0.000129
# 4                        7                 320           0.000128
#
#     output_token_pricing                                       chapter_text  \
# 31              0.000016  1 "Dr. E" (1234567890)\n00:00:00.000 --> 00:00...
# 30              0.000010  996 "Dr. M" (2345678901)\n10:02:15.340 --> 10:...
# 33              0.000010  1001 "Dr. S" (3456789012)\n10:02:42.520 --> 10...
# 32              0.000006  1006 "Dr. D" (4567890123)\n10:03:13.400 --> 10...
# 35              0.000014  1011 "Dr. E" (1234567890)\n10:03:44.900 --> 10...
# 34              0.000016  1015 "Dr. E" (1234567890)\n10:04:10.100 --> 10...
# 19              0.000016  1 "Dr. E" (1234567890)\n00:00:00.000 --> 00:00...
# 18              0.000011  996 "Dr. M" (2345678901)\n10:02:15.340 --> 10:...
# 21              0.000011  1001 "Dr. S" (3456789012)\n10:02:42.520 --> 10...
# 20              0.000014  1006 "Dr. D" (4567890123)\n10:03:13.400 --> 10...
# 23              0.000015  1011 "Dr. E" (1234567890)\n10:03:44.900 --> 10...
# 22              0.000013  1015 "Dr. E" (1234567890)\n10:04:10.100 --> 10...
# 13              0.000150  1 "Dr. E" (1234567890)\n00:00:00.000 --> 00:00...
# 12              0.000120  996 "Dr. M" (2345678901)\n10:02:15.340 --> 10:...
# 15              0.000120  1001 "Dr. S" (3456789012)\n10:02:42.520 --> 10...
# 14              0.000135  1006 "Dr. D" (4567890123)\n10:03:13.400 --> 10...
# 17              0.000135  1011 "Dr. E" (1234567890)\n10:03:44.900 --> 10...
# 16              0.000105  1015 "Dr. E" (1234567890)\n10:04:10.100 --> 10...
# 7               0.000031  1 "Dr. E" (1234567890)\n00:00:00.000 --> 00:00...
# 6               0.000021  996 "Dr. M" (2345678901)\n10:02:15.340 --> 10:...
# 9               0.000025  1001 "Dr. S" (3456789012)\n10:02:42.520 --> 10...
# 8               0.000018  1006 "Dr. D" (4567890123)\n10:03:13.400 --> 10...
# 11              0.000028  1011 "Dr. E" (1234567890)\n10:03:44.900 --> 10...
# 10              0.000025  1015 "Dr. E" (1234567890)\n10:04:10.100 --> 10...
# 1               0.000005  1 "Dr. E" (1234567890)\n00:00:00.000 --> 00:00...
# 0               0.000004  996 "Dr. M" (2345678901)\n10:02:15.340 --> 10:...
# 3               0.000004  1001 "Dr. S" (3456789012)\n10:02:42.520 --> 10...
# 2               0.000003  1006 "Dr. D" (4567890123)\n10:03:13.400 --> 10...
# 5               0.000004  1011 "Dr. E" (1234567890)\n10:03:44.900 --> 10...
# 4               0.000004  1015 "Dr. E" (1234567890)\n10:04:10.100 --> 10...
#
#                                        original_title  rouge_l_f1_score  \
# 31    Discussing the Higgs Boson and Its Implications            0.8333
# 30     Exploring Future Frontiers in Particle Physics            0.4444
# 33          The Quest for a Theory of Quantum Gravity            0.3636
# 32  Exploring Higher Dimensions and the Fabric of ...            0.4000
# 35  The Role of Theory and Experimentation in Physics            0.3077
# 34          Antimatter and Its Potential Applications            0.3636
# 19    Discussing the Higgs Boson and Its Implications            0.3636
# 18     Exploring Future Frontiers in Particle Physics            0.4444
# 21          The Quest for a Theory of Quantum Gravity            0.3636
# 20  Exploring Higher Dimensions and the Fabric of ...            0.0000
# 23  The Role of Theory and Experimentation in Physics            0.1667
# 22          Antimatter and Its Potential Applications            0.4444
# 13    Discussing the Higgs Boson and Its Implications            0.4000
# 12     Exploring Future Frontiers in Particle Physics            0.6000
# 15          The Quest for a Theory of Quantum Gravity            0.3636
# 14  Exploring Higher Dimensions and the Fabric of ...            0.1667
# 17  The Role of Theory and Experimentation in Physics            0.1818
# 16          Antimatter and Its Potential Applications            0.5714
# 7     Discussing the Higgs Boson and Its Implications            0.6000
# 6      Exploring Future Frontiers in Particle Physics            0.4444
# 9           The Quest for a Theory of Quantum Gravity            0.3636
# 8   Exploring Higher Dimensions and the Fabric of ...            0.4000
# 11  The Role of Theory and Experimentation in Physics            0.0000
# 10          Antimatter and Its Potential Applications            0.5714
# 1     Discussing the Higgs Boson and Its Implications            0.4000
# 0      Exploring Future Frontiers in Particle Physics            0.6000
# 3           The Quest for a Theory of Quantum Gravity            0.3636
# 2   Exploring Higher Dimensions and the Fabric of ...            0.4000
# 5   The Role of Theory and Experimentation in Physics            0.0000
# 4           Antimatter and Its Potential Applications            0.5714
#
#     cosine_similarity
# 31           0.856295
# 30           0.851623
# 33           0.833529
# 32           0.746537
# 35           0.220735
# 34           0.816674
# 19           0.712618
# 18           0.880063
# 21           0.891044
# 20           0.675618
# 23           0.540373
# 22           0.890370
# 13           0.858185
# 12           0.878752
# 15           0.767698
# 14           0.718587
# 17           0.571397
# 16           0.938167
# 7            0.807500
# 6            0.773196
# 9            0.814376
# 8            0.746537
# 11           0.422520
# 10           0.938167
# 1            0.858185
# 0            0.878752
# 3            0.814376
# 2            0.746537
# 5            0.285518
# 4            0.938167

# %%
metrics_dir = config['dir']['metrics']
# Create the directory if it doesn't exist
os.makedirs(metrics_dir, exist_ok=True)
# Construct the file path
metrics_file_path = os.path.join(metrics_dir, config['dir']['metrics_file'])
df.to_csv(metrics_file_path, index=False)

# %%
df_summary = df.groupby('model_id').mean(numeric_only=True)
if 'rouge_l_f1_score' and 'cosine_similarity' in df_summary.columns:
    df_summary = df_summary.rename(columns={'rouge_l_f1_score': 'mean_rouge_l_f1_score', 'cosine_similarity': 'mean_cosine_similarity'})
df_summary['p95_latency_seconds'] = df.groupby('model_id')['latency_seconds'].quantile(0.95)
df_summary['avg_cost_per_txn'] = df_summary.input_token_price + df_summary.output_token_pricing
df_summary['p95_cost_per_txn'] = df.groupby('model_id')['input_token_price'].quantile(0.95) + \
                                 df.groupby('model_id')['output_token_pricing'].quantile(0.95)
df_summary.completion_token_count = df_summary.completion_token_count.astype(int)
df_summary.prompt_token_count = df_summary.prompt_token_count.astype(int)
df_summary['p95_completion_token_count'] = df.groupby('model_id')['completion_token_count'].quantile(0.95)
df_summary['p95_prompt_token_count'] = df.groupby('model_id')['prompt_token_count'].quantile(0.95)
df_summary = df_summary.drop(columns=['chapter_id'])
# Reset the index to make 'model_id' a column
df_summary = df_summary.reset_index()
df_summary
# Out:
#                                   model_id  latency_seconds  \
# 0             amazon.titan-text-express-v1         1.126562
# 1   anthropic.claude-3-haiku-20240307-v1:0         0.762285
# 2  anthropic.claude-3-sonnet-20240229-v1:0         1.122653
# 3                  meta.llama2-13b-chat-v1         1.293597
# 4            meta.llama3-70b-instruct-v1:0         0.964386
# 5             meta.llama3-8b-instruct-v1:0         0.754584
# 6         mistral.mistral-7b-instruct-v0:2         0.984149
# 7       mistral.mixtral-8x7b-instruct-v0:1         0.675825
#
#    completion_token_count  prompt_token_count  input_token_price  \
# 0                       7                 385           0.000309
# 1                      14                 441           0.000110
# 2                      13                 441           0.001324
# 3                      15                 488           0.000366
# 4                       7                 347           0.000920
# 5                       6                 347           0.000139
# 6                      35                 401           0.000060
# 7                       5                 339           0.000153
#
#    output_token_pricing  mean_rouge_l_f1_score  mean_cosine_similarity  \
# 0              0.000012               0.452100                0.720899
# 1              0.000018               0.297117                0.765014
# 2              0.000202               0.380583                0.788797
# 3              0.000016                    NaN                     NaN
# 4              0.000024               0.396567                0.750383
# 5              0.000004               0.389167                0.753589
# 6              0.000007               0.327533                0.631595
# 7              0.000004               0.389167                0.761117
#
#    p95_latency_seconds  avg_cost_per_txn  p95_cost_per_txn  \
# 0             1.299742          0.000321          0.000508
# 1             0.962902          0.000129          0.000205
# 2             1.814916          0.001526          0.002480
# 3             1.694030          0.000382          0.000499
# 4             1.114516          0.000944          0.001002
# 5             0.766312          0.000143          0.000151
# 6             1.887510          0.000067          0.000113
# 7             0.736683          0.000157          0.000166
#
#    p95_completion_token_count  p95_prompt_token_count
# 0                       11.65                  611.90
# 1                       23.10                  703.85
# 2                       24.55                  703.85
# 3                       25.75                  631.30
# 4                        8.75                  366.50
# 5                        7.75                  366.50
# 6                       95.50                  627.90
# 7                        6.75                  358.50

# %% [markdown]
# #### Calculate the long short view of the completions

# %%
# handle if the title is given in the data frame, include it in the pivoted df, else exclude it
if 'original_title'in df.columns:
    index_cols = ['file_name', 'chapter_id', 'chapter_text', 'original_title']
else:
    index_cols = ['file_name', 'chapter_id', 'chapter_text']
    
df_pivoted = df.pivot_table(index=index_cols, columns='model_id', values='chapter_title', aggfunc='first')
cols_other_than_index_cols = [f"{c}_title" for c in df_pivoted.columns if c not in index_cols]
df_pivoted = df_pivoted.reset_index()
df_pivoted.columns = index_cols + cols_other_than_index_cols
df_pivoted.head()
# Out:
#                        file_name  chapter_id  \
# 0  particle_physics_meeting.json           0
# 1  particle_physics_meeting.json           1
# 2  particle_physics_meeting.json           2
# 3  particle_physics_meeting.json           3
# 4  particle_physics_meeting.json           4
#
#                                         chapter_text  \
# 0  1 "Dr. E" (1234567890)\n00:00:00.000 --> 00:00...
# 1  996 "Dr. M" (2345678901)\n10:02:15.340 --> 10:...
# 2  1001 "Dr. S" (3456789012)\n10:02:42.520 --> 10...
# 3  1006 "Dr. D" (4567890123)\n10:03:13.400 --> 10...
# 4  1011 "Dr. E" (1234567890)\n10:03:44.900 --> 10...
#
#                                       original_title  \
# 0    Discussing the Higgs Boson and Its Implications
# 1     Exploring Future Frontiers in Particle Physics
# 2          The Quest for a Theory of Quantum Gravity
# 3  Exploring Higher Dimensions and the Fabric of ...
# 4  The Role of Theory and Experimentation in Physics
#
#    amazon.titan-text-express-v1_title  \
# 0    Higgs Boson and its Implications
# 1          Particle Physics Prospects
# 2           Exploring Quantum Gravity
# 3                   Higher Dimensions
# 4  Exploring the Frontiers of Reality
#
#   anthropic.claude-3-haiku-20240307-v1:0_title  \
# 0             Higgs Boson Particle Discoveries
# 1                   Particle Physics Frontiers
# 2                     Quantum Gravity Theories
# 3           Multidimensional Universe Theories
# 4           Probing Particle Physics Frontiers
#
#   anthropic.claude-3-sonnet-20240229-v1:0_title  \
# 0                        Higgs Boson Discussion
# 1                    Future of Particle Physics
# 2                    Quantum Gravity Discussion
# 3                  Dimensions Beyond Space-Time
# 4                   Probing Fundamental Physics
#
#   meta.llama3-70b-instruct-v1:0_title meta.llama3-8b-instruct-v1:0_title  \
# 0            Higgs Boson Implications             Higgs Boson Discussion
# 1                   Future of Physics         Future of Particle Physics
# 2        Quantum Gravity Implications       Quantum Gravity Implications
# 3                   Higher Dimensions                  Higher Dimensions
# 4            Probing Reality's Fabric              Particle Accelerators
#
#   mistral.mistral-7b-instruct-v0:2_title  \
# 0                     Higgs Applications
# 1                Future Physics Projects
# 2            Quantum Gravity Discussions
# 3               Higher Dimensions Debate
# 4                           New Insights
#
#   mistral.mixtral-8x7b-instruct-v0:1_title
# 0                   Higgs Boson Discussion
# 1               Future of Particle Physics
# 2                 Quantum Gravity Theories
# 3                        Higher Dimensions
# 4                        Exploring Reality

# %%
# Construct the file path
movel_evals_fpath = os.path.join(metrics_dir, config['dir']['model_evals_file'])
df_pivoted.to_csv(movel_evals_fpath, index=False)
df_pivoted.head()
# Out:
#                        file_name  chapter_id  \
# 0  particle_physics_meeting.json           0
# 1  particle_physics_meeting.json           1
# 2  particle_physics_meeting.json           2
# 3  particle_physics_meeting.json           3
# 4  particle_physics_meeting.json           4
#
#                                         chapter_text  \
# 0  1 "Dr. E" (1234567890)\n00:00:00.000 --> 00:00...
# 1  996 "Dr. M" (2345678901)\n10:02:15.340 --> 10:...
# 2  1001 "Dr. S" (3456789012)\n10:02:42.520 --> 10...
# 3  1006 "Dr. D" (4567890123)\n10:03:13.400 --> 10...
# 4  1011 "Dr. E" (1234567890)\n10:03:44.900 --> 10...
#
#                                       original_title  \
# 0    Discussing the Higgs Boson and Its Implications
# 1     Exploring Future Frontiers in Particle Physics
# 2          The Quest for a Theory of Quantum Gravity
# 3  Exploring Higher Dimensions and the Fabric of ...
# 4  The Role of Theory and Experimentation in Physics
#
#    amazon.titan-text-express-v1_title  \
# 0    Higgs Boson and its Implications
# 1          Particle Physics Prospects
# 2           Exploring Quantum Gravity
# 3                   Higher Dimensions
# 4  Exploring the Frontiers of Reality
#
#   anthropic.claude-3-haiku-20240307-v1:0_title  \
# 0             Higgs Boson Particle Discoveries
# 1                   Particle Physics Frontiers
# 2                     Quantum Gravity Theories
# 3           Multidimensional Universe Theories
# 4           Probing Particle Physics Frontiers
#
#   anthropic.claude-3-sonnet-20240229-v1:0_title  \
# 0                        Higgs Boson Discussion
# 1                    Future of Particle Physics
# 2                    Quantum Gravity Discussion
# 3                  Dimensions Beyond Space-Time
# 4                   Probing Fundamental Physics
#
#   meta.llama3-70b-instruct-v1:0_title meta.llama3-8b-instruct-v1:0_title  \
# 0            Higgs Boson Implications             Higgs Boson Discussion
# 1                   Future of Physics         Future of Particle Physics
# 2        Quantum Gravity Implications       Quantum Gravity Implications
# 3                   Higher Dimensions                  Higher Dimensions
# 4            Probing Reality's Fabric              Particle Accelerators
#
#   mistral.mistral-7b-instruct-v0:2_title  \
# 0                     Higgs Applications
# 1                Future Physics Projects
# 2            Quantum Gravity Discussions
# 3               Higher Dimensions Debate
# 4                           New Insights
#
#   mistral.mixtral-8x7b-instruct-v0:1_title
# 0                   Higgs Boson Discussion
# 1               Future of Particle Physics
# 2                 Quantum Gravity Theories
# 3                        Higher Dimensions
# 4                        Exploring Reality

# %%
df_summary
# Out:
#                                   model_id  latency_seconds  \
# 0             amazon.titan-text-express-v1         1.126562
# 1   anthropic.claude-3-haiku-20240307-v1:0         0.762285
# 2  anthropic.claude-3-sonnet-20240229-v1:0         1.122653
# 3                  meta.llama2-13b-chat-v1         1.293597
# 4            meta.llama3-70b-instruct-v1:0         0.964386
# 5             meta.llama3-8b-instruct-v1:0         0.754584
# 6         mistral.mistral-7b-instruct-v0:2         0.984149
# 7       mistral.mixtral-8x7b-instruct-v0:1         0.675825
#
#    completion_token_count  prompt_token_count  input_token_price  \
# 0                       7                 385           0.000309
# 1                      14                 441           0.000110
# 2                      13                 441           0.001324
# 3                      15                 488           0.000366
# 4                       7                 347           0.000920
# 5                       6                 347           0.000139
# 6                      35                 401           0.000060
# 7                       5                 339           0.000153
#
#    output_token_pricing  mean_rouge_l_f1_score  mean_cosine_similarity  \
# 0              0.000012               0.452100                0.720899
# 1              0.000018               0.297117                0.765014
# 2              0.000202               0.380583                0.788797
# 3              0.000016                    NaN                     NaN
# 4              0.000024               0.396567                0.750383
# 5              0.000004               0.389167                0.753589
# 6              0.000007               0.327533                0.631595
# 7              0.000004               0.389167                0.761117
#
#    p95_latency_seconds  avg_cost_per_txn  p95_cost_per_txn  \
# 0             1.299742          0.000321          0.000508
# 1             0.962902          0.000129          0.000205
# 2             1.814916          0.001526          0.002480
# 3             1.694030          0.000382          0.000499
# 4             1.114516          0.000944          0.001002
# 5             0.766312          0.000143          0.000151
# 6             1.887510          0.000067          0.000113
# 7             0.736683          0.000157          0.000166
#
#    p95_completion_token_count  p95_prompt_token_count
# 0                       11.65                  611.90
# 1                       23.10                  703.85
# 2                       24.55                  703.85
# 3                       25.75                  631.30
# 4                        8.75                  366.50
# 5                        7.75                  366.50
# 6                       95.50                  627.90
# 7                        6.75                  358.50

# %%
def create_summary(row, summary):
    return summary.format(
                model_id=row.name,
                avg_latency=round(row['latency_seconds'], 4),
                p95_latency=round(row['p95_latency_seconds'], 4),
                avg_cost=round(10000 * row['avg_cost_per_txn'], 6),
                p95_cost_per_txn=round(10000 * row['p95_cost_per_txn'], 6),
                avg_prompt_token_count=row['prompt_token_count'],
                p95_prompt_token_count=row['p95_prompt_token_count'],
                avg_completion_token_count=row['completion_token_count'],
                p95_completion_token_count=row['p95_completion_token_count'],
                mean_rouge_l_score=('None' if row.get('mean_rouge_l_f1_score') is None else round(row['mean_rouge_l_f1_score'], 4)),
                mean_cosine_similarity_score=('None, (no human generated title provided in the data)' if row.get('mean_cosine_similarity') is None else round(row['mean_cosine_similarity'], 4)),
                count=int(row['count'])
            )
df_summary = pd.merge(left=df_summary, right=df_per_model_id_counts, on="model_id", how="left")

df_summary['overall_report'] = df_summary.apply(lambda r: create_summary(r, config['report']['summary_text']), axis=1)
df_summary = df_summary.round(6)
summary_metrics_file_path = os.path.join(metrics_dir, config['dir']['summary_metrics_file'])
df_summary = df_summary.sort_values(by=['mean_cosine_similarity', 'mean_rouge_l_f1_score'], ascending=False)
df_summary.to_csv(summary_metrics_file_path, index=False)

# %%
# view the df_summary elements
df_summary.head(10)
# Out:
#                                   model_id  latency_seconds  \
# 2  anthropic.claude-3-sonnet-20240229-v1:0         1.122653
# 1   anthropic.claude-3-haiku-20240307-v1:0         0.762285
# 7       mistral.mixtral-8x7b-instruct-v0:1         0.675825
# 5             meta.llama3-8b-instruct-v1:0         0.754584
# 4            meta.llama3-70b-instruct-v1:0         0.964386
# 0             amazon.titan-text-express-v1         1.126562
# 6         mistral.mistral-7b-instruct-v0:2         0.984149
# 3                  meta.llama2-13b-chat-v1         1.293597
#
#    completion_token_count  prompt_token_count  input_token_price  \
# 2                      13                 441           0.001324
# 1                      14                 441           0.000110
# 7                       5                 339           0.000153
# 5                       6                 347           0.000139
# 4                       7                 347           0.000920
# 0                       7                 385           0.000309
# 6                      35                 401           0.000060
# 3                      15                 488           0.000366
#
#    output_token_pricing  mean_rouge_l_f1_score  mean_cosine_similarity  \
# 2              0.000202               0.380583                0.788797
# 1              0.000018               0.297117                0.765014
# 7              0.000004               0.389167                0.761117
# 5              0.000004               0.389167                0.753589
# 4              0.000024               0.396567                0.750383
# 0              0.000012               0.452100                0.720899
# 6              0.000007               0.327533                0.631595
# 3              0.000016                    NaN                     NaN
#
#    p95_latency_seconds  avg_cost_per_txn  p95_cost_per_txn  \
# 2             1.814916          0.001526          0.002480
# 1             0.962902          0.000129          0.000205
# 7             0.736683          0.000157          0.000166
# 5             0.766312          0.000143          0.000151
# 4             1.114516          0.000944          0.001002
# 0             1.299742          0.000321          0.000508
# 6             1.887510          0.000067          0.000113
# 3             1.694030          0.000382          0.000499
#
#    p95_completion_token_count  p95_prompt_token_count  count  \
# 2                       24.55                  703.85     10
# 1                       23.10                  703.85     10
# 7                        6.75                  358.50      6
# 5                        7.75                  366.50      6
# 4                        8.75                  366.50      6
# 0                       11.65                  611.90     10
# 6                       95.50                  627.90     10
# 3                       25.75                  631.30      4
#
#                                       overall_report
# 2  The average inference latency for this workloa...
# 1  The average inference latency for this workloa...
# 7  The average inference latency for this workloa...
# 5  The average inference latency for this workloa...
# 4  The average inference latency for this workloa...
# 0  The average inference latency for this workloa...
# 6  The average inference latency for this workloa...
# 3  The average inference latency for this workloa...

# %% [markdown]
# ### Title Evaluation: Using LLM as a Judge in the loop
# ---
#
# In this portion:
#
# 1. Titles generated by each model are evaluated on relevance and meaning by [Claude](https://www.anthropic.com/news/claude-3-family) Sonnet/Your model of choice. Prompt for the model that acts as a judge in the loop can be viewed in: [eval_template.txt](data/prompts/eval_template.txt). Edit and review this prompt based on the use case and criteria for subjective evaluation.
#
# 2. The role of the model acting as a judge it to compare the titles generated by each model to a human generated title (Aka ***golden title***). It provides information on the selected model, title, and an explanation of its selection, with an in depth analysis of comparison between other titles and why it chose the one it did. In this case, the model as a judge is prompted to ***capture the most relevant aspects of the meeting*** while generating a title.
#
# 3. A final evaluation metric is calculated that shows the distribution of the selected models and their respective titles. This will give a judgement call of which model to use in production ready workloads.
#
# ***Note: For more information on the use of having a Model act as a judge, view: https://huggingface.co/learn/cookbook/en/llm_judge***

# %%
try:
    # convert the model evaluation metrics stored as a df 
    model_eval_df = pd.read_csv(os.path.join(config['dir']['metrics'], config['dir']['model_evals_file']))  
    logger.info(f"Model eval file found with all model completions. Ready to evaluate responses...")
    model_eval_df.head()
except Exception as e:
    logger.error(f"Model evaluation csv file not found in the directory. Error: {e}")
model_eval_df.head(10)
# Out:
# [2024-06-01 17:14:37,603] p163 {1587218011.py:4} INFO - Model eval file found with all model completions. Ready to evaluate responses...
#                        file_name  chapter_id  \
# 0  particle_physics_meeting.json           0
# 1  particle_physics_meeting.json           1
# 2  particle_physics_meeting.json           2
# 3  particle_physics_meeting.json           3
# 4  particle_physics_meeting.json           4
# 5  particle_physics_meeting.json           5
#
#                                         chapter_text  \
# 0  1 "Dr. E" (1234567890)\n00:00:00.000 --> 00:00...
# 1  996 "Dr. M" (2345678901)\n10:02:15.340 --> 10:...
# 2  1001 "Dr. S" (3456789012)\n10:02:42.520 --> 10...
# 3  1006 "Dr. D" (4567890123)\n10:03:13.400 --> 10...
# 4  1011 "Dr. E" (1234567890)\n10:03:44.900 --> 10...
# 5  1015 "Dr. E" (1234567890)\n10:04:10.100 --> 10...
#
#                                       original_title  \
# 0    Discussing the Higgs Boson and Its Implications
# 1     Exploring Future Frontiers in Particle Physics
# 2          The Quest for a Theory of Quantum Gravity
# 3  Exploring Higher Dimensions and the Fabric of ...
# 4  The Role of Theory and Experimentation in Physics
# 5          Antimatter and Its Potential Applications
#
#              amazon.titan-text-express-v1_title  \
# 0              Higgs Boson and its Implications
# 1                    Particle Physics Prospects
# 2                     Exploring Quantum Gravity
# 3                             Higher Dimensions
# 4            Exploring the Frontiers of Reality
# 5  Antimatter in Medicine and Space Exploration
#
#   anthropic.claude-3-haiku-20240307-v1:0_title  \
# 0             Higgs Boson Particle Discoveries
# 1                   Particle Physics Frontiers
# 2                     Quantum Gravity Theories
# 3           Multidimensional Universe Theories
# 4           Probing Particle Physics Frontiers
# 5            Antimatter's Scientific Potential
#
#   anthropic.claude-3-sonnet-20240229-v1:0_title  \
# 0                        Higgs Boson Discussion
# 1                    Future of Particle Physics
# 2                    Quantum Gravity Discussion
# 3                  Dimensions Beyond Space-Time
# 4                   Probing Fundamental Physics
# 5                       Antimatter Applications
#
#   meta.llama3-70b-instruct-v1:0_title meta.llama3-8b-instruct-v1:0_title  \
# 0            Higgs Boson Implications             Higgs Boson Discussion
# 1                   Future of Physics         Future of Particle Physics
# 2        Quantum Gravity Implications       Quantum Gravity Implications
# 3                   Higher Dimensions                  Higher Dimensions
# 4            Probing Reality's Fabric              Particle Accelerators
# 5             Antimatter Applications            Antimatter Applications
#
#   mistral.mistral-7b-instruct-v0:2_title  \
# 0                     Higgs Applications
# 1                Future Physics Projects
# 2            Quantum Gravity Discussions
# 3               Higher Dimensions Debate
# 4                           New Insights
# 5                Antimatter Applications
#
#   mistral.mixtral-8x7b-instruct-v0:1_title
# 0                   Higgs Boson Discussion
# 1               Future of Particle Physics
# 2                 Quantum Gravity Theories
# 3                        Higher Dimensions
# 4                        Exploring Reality
# 5                  Antimatter Applications

# %% [markdown]
# #### Prepare the evaluation prompt payloads
#
# Here, the [`evaluation prompt template`](data/prompts/eval_template.txt) is used by the LLM judge to evaluate different chapter titles and suggest the most suitable title based on the evaluation criteria mentioned in the prompt template.

# %%
def prepare_eval_prompts(row):
    """
    This function evaluates the prompts by incorporating all of the titles generated by various bedrock models into the evaluation prompt template.
    """
    # represents the eval template used by the model judge
    eval_template: Optional[str] = None
    processed_eval_template: Optional[str] = None
    model_titles: List[str] = []
    try:
        # file path to the eval template
        eval_template_path: str = os.path.join(config['dir']['prompts'], config['eval_model_info'].get('prompt_template'))
        with open(eval_template_path, "r") as f:
            eval_template = f.read()
            logger.info(f"evaluation prompt template recorded: {eval_template}")
    except FileNotFoundError:
        print(f"Error: Evaluation template not found at {eval_template_path}")
    logger.info(f"chapter_text: {row['chapter_text']}")
    logger.info(f"original_title: {row['original_title']}")
    for column in row.index:
        if column.endswith("_title") and column != "original_title":
            model_id = column.split("_title")[0]
            model_title = row[column]
            model_titles.append(f"\n<{model_id}>\n{model_title}\n</{model_id}>\n")
    processed_eval_template = eval_template.format(
        chapter_text=row['chapter_text'], 
        original_title=row['original_title'],
        model_titles="\n".join(model_titles)
    )

    return processed_eval_template

# %% [markdown]
# Add `evaluation prompt` as a column into a df with respective model and chapter titles to send into the Model for further evaluation in the loop

# %%
if model_eval_df is not None:
    model_eval_df['eval_prompt'] = model_eval_df.apply(lambda r: prepare_eval_prompts(r), axis=1)
    logger.info("preparing the evaluation prompt templates for the LLM judge....")
else:
    logger.error(f"Model evaluation dataset is not available to process.")
model_eval_df_f_path = os.path.join(metrics_dir, config['dir']['processed_prompts_for_eval'])
model_eval_df.to_csv(model_eval_df_f_path, index=False)
model_eval_df.head(10)
# Out:
# [2024-06-01 17:14:37,618] p163 {2540286596.py:14} INFO - evaluation prompt template recorded: Human: here is a transcript from a meeting in the <chapter></chapter> tag followed by chapter titles generated by different models.
# Your task is to select the title that best captures the content and meaning of the chapter in 1 to 4 words.
# Put the selected title, model name and explanation for selecting the title and not selecting other titles in a JSON as within 3 elements: "best_match_title", "selected_model", and "explanation".
# Your explanation should include both model name and title so that it is simple to understand which title was generated by which model and why it was or was not selected.
#
# <chapter>
# {chapter_text}
# </chapter>
#
# <model_x>
# {original_title}
# </model_x>
#
# {model_titles}
#
# Assistant: Here is the response in json:
#
# [2024-06-01 17:14:37,618] p163 {2540286596.py:17} INFO - chapter_text: 1 "Dr. E" (1234567890)
# 00:00:00.000 --> 00:00:05.340
# Have you all seen the latest results from the Large Hadron Collider? The data on the Higgs boson is quite fascinating.
#
# 2 "Dr. M" (2345678901)
# 00:00:05.340 --> 00:00:10.720
# Yes, I've been studying the particle trajectories closely. The decay patterns are consistent with our theoretical models.
#
# 3 "Dr. S" (3456789012)
# 00:00:10.720 --> 00:00:16.500
# I'm more interested in the potential applications of these findings. Could we harness the Higgs field for energy production?
#
# 4 "Dr. D" (4567890123)
# 00:00:16.500 --> 00:00:21.870
# That's an intriguing idea, but we'd need to overcome some significant technical hurdles first.
#
# 5 "Dr. E" (1234567890)
# 00:00:21.870 --> 00:00:27.140
# Absolutely. Have you considered the implications of these findings on our understanding of dark matter?
# [2024-06-01 17:14:37,618] p163 {2540286596.py:18} INFO - original_title: Discussing the Higgs Boson and Its Implications
# [2024-06-01 17:14:37,619] p163 {2540286596.py:14} INFO - evaluation prompt template recorded: Human: here is a transcript from a meeting in the <chapter></chapter> tag followed by chapter titles generated by different models.
# Your task is to select the title that best captures the content and meaning of the chapter in 1 to 4 words.
# Put the selected title, model name and explanation for selecting the title and not selecting other titles in a JSON as within 3 elements: "best_match_title", "selected_model", and "explanation".
# Your explanation should include both model name and title so that it is simple to understand which title was generated by which model and why it was or was not selected.
#
# <chapter>
# {chapter_text}
# </chapter>
#
# <model_x>
# {original_title}
# </model_x>
#
# {model_titles}
#
# Assistant: Here is the response in json:
#
# [2024-06-01 17:14:37,619] p163 {2540286596.py:17} INFO - chapter_text: 996 "Dr. M" (2345678901)
# 10:02:15.340 --> 10:02:20.720
# The upcoming run at the Tevatron should provide us with even more data to analyze.
#
# 997 "Dr. S" (3456789012)
# 10:02:20.720 --> 10:02:26.500
# Don't forget about the proposed muon collider project. That could open up new frontiers in high-energy physics.
#
# 998 "Dr. D" (4567890123)
# 10:02:26.500 --> 10:02:31.870
# True, but the funding challenges for such a large-scale endeavor are substantial.
#
# 999 "Dr. E" (1234567890)
# 10:02:31.870 --> 10:02:37.140
# Regardless, the future of particle physics is full of exciting possibilities.
#
# 1000 "Dr. M" (2345678901)
# 10:02:37.140 --> 10:02:42.520
# Indeed. As long as we continue to ask questions and push the boundaries of our knowledge, we'll make groundbreaking discoveries.
# [2024-06-01 17:14:37,619] p163 {2540286596.py:18} INFO - original_title: Exploring Future Frontiers in Particle Physics
# [2024-06-01 17:14:37,620] p163 {2540286596.py:14} INFO - evaluation prompt template recorded: Human: here is a transcript from a meeting in the <chapter></chapter> tag followed by chapter titles generated by different models.
# Your task is to select the title that best captures the content and meaning of the chapter in 1 to 4 words.
# Put the selected title, model name and explanation for selecting the title and not selecting other titles in a JSON as within 3 elements: "best_match_title", "selected_model", and "explanation".
# Your explanation should include both model name and title so that it is simple to understand which title was generated by which model and why it was or was not selected.
#
# <chapter>
# {chapter_text}
# </chapter>
#
# <model_x>
# {original_title}
# </model_x>
#
# {model_titles}
#
# Assistant: Here is the response in json:
#
# [2024-06-01 17:14:37,620] p163 {2540286596.py:17} INFO - chapter_text: 1001 "Dr. S" (3456789012)
# 10:02:42.520 --> 10:02:48.200
# Speaking of pushing boundaries, have you all considered the potential implications of quantum gravity on our current models?
#
# 1002 "Dr. D" (4567890123)
# 10:02:48.200 --> 10:02:54.600
# Ah, the elusive theory of everything. That's been a Holy Grail for physicists ever since Einstein's time.
#
# 1003 "Dr. E" (1234567890)
# 10:02:54.600 --> 10:03:00.900
# Quantum gravity could potentially reconcile the disparities between general relativity and quantum mechanics.
#
# 1004 "Dr. M" (2345678901)
# 10:03:00.900 --> 10:03:07.100
# But the mathematical complexities involved are mind-boggling. String theory is one approach, but it's far from complete.
#
# 1005 "Dr. S" (3456789012)
# 10:03:07.100 --> 10:03:13.400
# What about loop quantum gravity? That's another promising avenue, although the experimental verification is lacking.
# [2024-06-01 17:14:37,620] p163 {2540286596.py:18} INFO - original_title: The Quest for a Theory of Quantum Gravity
# [2024-06-01 17:14:37,621] p163 {2540286596.py:14} INFO - evaluation prompt template recorded: Human: here is a transcript from a meeting in the <chapter></chapter> tag followed by chapter titles generated by different models.
# Your task is to select the title that best captures the content and meaning of the chapter in 1 to 4 words.
# Put the selected title, model name and explanation for selecting the title and not selecting other titles in a JSON as within 3 elements: "best_match_title", "selected_model", and "explanation".
# Your explanation should include both model name and title so that it is simple to understand which title was generated by which model and why it was or was not selected.
#
# <chapter>
# {chapter_text}
# </chapter>
#
# <model_x>
# {original_title}
# </model_x>
#
# {model_titles}
#
# Assistant: Here is the response in json:
#
# [2024-06-01 17:14:37,621] p163 {2540286596.py:17} INFO - chapter_text: 1006 "Dr. D" (4567890123)
# 10:03:13.400 --> 10:03:19.700
# Precisely. Without empirical data to support these theories, they remain highly speculative at this stage.
#
# 1007 "Dr. E" (1234567890)
# 10:03:19.700 --> 10:03:26.000
# Perhaps the answers lie in dimensions beyond our current understanding of space-time.
#
# 1008 "Dr. M" (2345678901)
# 10:03:26.000 --> 10:03:32.300
# Ah, the mystical world of higher dimensions. That's where things really start to bend our minds.
#
# 1009 "Dr. S" (3456789012)
# 10:03:32.300 --> 10:03:38.600
# Agreed. The notion of a multidimensional universe is both fascinating and perplexing.
#
# 1010 "Dr. D" (4567890123)
# 10:03:38.600 --> 10:03:44.900
# It's a tantalizing concept, but one that may forever elude our observational capabilities.
# [2024-06-01 17:14:37,621] p163 {2540286596.py:18} INFO - original_title: Exploring Higher Dimensions and the Fabric of Reality
# [2024-06-01 17:14:37,621] p163 {2540286596.py:14} INFO - evaluation prompt template recorded: Human: here is a transcript from a meeting in the <chapter></chapter> tag followed by chapter titles generated by different models.
# Your task is to select the title that best captures the content and meaning of the chapter in 1 to 4 words.
# Put the selected title, model name and explanation for selecting the title and not selecting other titles in a JSON as within 3 elements: "best_match_title", "selected_model", and "explanation".
# Your explanation should include both model name and title so that it is simple to understand which title was generated by which model and why it was or was not selected.
#
# <chapter>
# {chapter_text}
# </chapter>
#
# <model_x>
# {original_title}
# </model_x>
#
# {model_titles}
#
# Assistant: Here is the response in json:
#
# [2024-06-01 17:14:37,622] p163 {2540286596.py:17} INFO - chapter_text: 1011 "Dr. E" (1234567890)
# 10:03:44.900 --> 10:03:51.200
# Not necessarily. With the advent of more powerful particle accelerators, we may be able to probe deeper into the fabric of reality.
#
# 1012 "Dr. M" (2345678901)
# 10:03:51.200 --> 10:03:57.500
# You raise a fair point. The upcoming upgrades to the Large Hadron Collider could potentially reveal new insights.
#
# 1013 "Dr. S" (3456789012)
# 10:03:57.500 --> 10:04:03.800
# And let's not forget the importance of theoretical work. Sometimes the math leads us to unexpected places.
#
# 1014 "Dr. D" (4567890123)
# 10:04:03.800 --> 10:04:10.100
# Absolutely. Some of the greatest breakthroughs in physics have come from pure thought experiments and mathematical models.
# [2024-06-01 17:14:37,622] p163 {2540286596.py:18} INFO - original_title: The Role of Theory and Experimentation in Physics
# [2024-06-01 17:14:37,622] p163 {2540286596.py:14} INFO - evaluation prompt template recorded: Human: here is a transcript from a meeting in the <chapter></chapter> tag followed by chapter titles generated by different models.
# Your task is to select the title that best captures the content and meaning of the chapter in 1 to 4 words.
# Put the selected title, model name and explanation for selecting the title and not selecting other titles in a JSON as within 3 elements: "best_match_title", "selected_model", and "explanation".
# Your explanation should include both model name and title so that it is simple to understand which title was generated by which model and why it was or was not selected.
#
# <chapter>
# {chapter_text}
# </chapter>
#
# <model_x>
# {original_title}
# </model_x>
#
# {model_titles}
#
# Assistant: Here is the response in json:
#
# [2024-06-01 17:14:37,622] p163 {2540286596.py:17} INFO - chapter_text: 1015 "Dr. E" (1234567890)
# 10:04:10.100 --> 10:04:16.400
# Take the concept of antimatter, for instance. It was purely theoretical until we found ways to produce and study it.
#
# 1016 "Dr. M" (2345678901)
# 10:04:16.400 --> 10:04:22.700
# And now we're harnessing antimatter for medical applications like proton therapy and advanced imaging techniques.
#
# 1017 "Dr. S" (3456789012)
# 10:04:22.700 --> 10:04:29.000
# Not to mention the potential for antimatter-based propulsion systems, which could revolutionize space exploration.
#
# 1018 "Dr. D" (4567890123)
# 10:04:29.000 --> 10:04:35.300
# Ah yes, the dream of achieving faster-than-light travel. But we'd need to overcome some significant hurdles first.
# [2024-06-01 17:14:37,623] p163 {2540286596.py:18} INFO - original_title: Antimatter and Its Potential Applications
# [2024-06-01 17:14:37,623] p163 {2745590833.py:3} INFO - preparing the evaluation prompt templates for the LLM judge....
#                        file_name  chapter_id  \
# 0  particle_physics_meeting.json           0
# 1  particle_physics_meeting.json           1
# 2  particle_physics_meeting.json           2
# 3  particle_physics_meeting.json           3
# 4  particle_physics_meeting.json           4
# 5  particle_physics_meeting.json           5
#
#                                         chapter_text  \
# 0  1 "Dr. E" (1234567890)\n00:00:00.000 --> 00:00...
# 1  996 "Dr. M" (2345678901)\n10:02:15.340 --> 10:...
# 2  1001 "Dr. S" (3456789012)\n10:02:42.520 --> 10...
# 3  1006 "Dr. D" (4567890123)\n10:03:13.400 --> 10...
# 4  1011 "Dr. E" (1234567890)\n10:03:44.900 --> 10...
# 5  1015 "Dr. E" (1234567890)\n10:04:10.100 --> 10...
#
#                                       original_title  \
# 0    Discussing the Higgs Boson and Its Implications
# 1     Exploring Future Frontiers in Particle Physics
# 2          The Quest for a Theory of Quantum Gravity
# 3  Exploring Higher Dimensions and the Fabric of ...
# 4  The Role of Theory and Experimentation in Physics
# 5          Antimatter and Its Potential Applications
#
#              amazon.titan-text-express-v1_title  \
# 0              Higgs Boson and its Implications
# 1                    Particle Physics Prospects
# 2                     Exploring Quantum Gravity
# 3                             Higher Dimensions
# 4            Exploring the Frontiers of Reality
# 5  Antimatter in Medicine and Space Exploration
#
#   anthropic.claude-3-haiku-20240307-v1:0_title  \
# 0             Higgs Boson Particle Discoveries
# 1                   Particle Physics Frontiers
# 2                     Quantum Gravity Theories
# 3           Multidimensional Universe Theories
# 4           Probing Particle Physics Frontiers
# 5            Antimatter's Scientific Potential
#
#   anthropic.claude-3-sonnet-20240229-v1:0_title  \
# 0                        Higgs Boson Discussion
# 1                    Future of Particle Physics
# 2                    Quantum Gravity Discussion
# 3                  Dimensions Beyond Space-Time
# 4                   Probing Fundamental Physics
# 5                       Antimatter Applications
#
#   meta.llama3-70b-instruct-v1:0_title meta.llama3-8b-instruct-v1:0_title  \
# 0            Higgs Boson Implications             Higgs Boson Discussion
# 1                   Future of Physics         Future of Particle Physics
# 2        Quantum Gravity Implications       Quantum Gravity Implications
# 3                   Higher Dimensions                  Higher Dimensions
# 4            Probing Reality's Fabric              Particle Accelerators
# 5             Antimatter Applications            Antimatter Applications
#
#   mistral.mistral-7b-instruct-v0:2_title  \
# 0                     Higgs Applications
# 1                Future Physics Projects
# 2            Quantum Gravity Discussions
# 3               Higher Dimensions Debate
# 4                           New Insights
# 5                Antimatter Applications
#
#   mistral.mixtral-8x7b-instruct-v0:1_title  \
# 0                   Higgs Boson Discussion
# 1               Future of Particle Physics
# 2                 Quantum Gravity Theories
# 3                        Higher Dimensions
# 4                        Exploring Reality
# 5                  Antimatter Applications
#
#                                          eval_prompt
# 0  Human: here is a transcript from a meeting in ...
# 1  Human: here is a transcript from a meeting in ...
# 2  Human: here is a transcript from a meeting in ...
# 3  Human: here is a transcript from a meeting in ...
# 4  Human: here is a transcript from a meeting in ...
# 5  Human: here is a transcript from a meeting in ...

# %% [markdown]
# #### Using LLM (Claude) as a judge in the loop to evaluate and narrow down the titles generated by different models of choice

# %%
def llm_judge_json_evaluations(model_id: str, prompt: str):
    # represents the service name
    service_name: str = "bedrock"
    # represents creating the bedrock model to invoke the litellm api for response for titan, llama and claude
    bedrock_model: str = f"{service_name}/{model_id}"
    # represents the current aws region
    aws_region = boto3.Session().region_name 
    # initialize the response dict
    ret = dict(exception = None,
               prompt = prompt,
               completion = None,
               file_name = None,
               original_title = None, 
               # initializing to 0 since none type throws an error later, this is used to calculate price per token input/output on ODT pricing
               completion_token_count = 0,
               # initializing to 0 since none type throws an error later
               prompt_token_count=0,
               input_token_price = None, 
               output_token_pricing = None,
               model_id = model_id)
    body = ret['prompt']
    os.environ["AWS_REGION_NAME"] = aws_region
    parameters = config['inference_parameters_for_explanations']
    temperature = parameters.get('temperature', 0.1)
    caching = parameters.get('caching', False)
    max_tokens = parameters.get("max_tokens", 500)
    try:
        # Represents calling the litellm completion/messaging api utilizing the completion/embeddings API
        logger.info(f"Invoking {bedrock_model}......")
        response = completion(model=bedrock_model,
                              messages=[{ "content": body,"role": "user"}],
                              temperature=temperature,
                              max_tokens=max_tokens,
                              caching=caching)
        
        # iterate through the entire model response
        for idx, choice in enumerate(response.choices):
            # extract the message and the message's content from litellm
            if choice.message and choice.message.content:
                # extract the response from the dict
                ret["completion"] = choice.message.content.strip()
        # Extract number of input and completion prompt tokens (this is the same structure for embeddings and text generation models on Amazon Bedrock)
        ret['prompt_token_count'] = response.usage.prompt_tokens
        ret['completion_token_count'] = response.usage.completion_tokens
    except Exception as e:
        logger.error(f"Exception occurred during invoking {model_id}, exception={e}")
        ret['exception'] = e
    
    logger.info(f"completion: {ret['completion']}")
    return ret

# %%
def get_inference(i: int, row: Dict, total: int, model_info: Dict) -> Dict:
    # save all the responses from the model in a dictionary
    resp: Dict = {}
    print(f"row={row}")
    logger.info(f"row {i}/{total}, prompt_template={model_info['prompt_template']}, model_id={model_info['model']}")
    model_id = model_info['model']
    # create the payload for model inference
    prompt = row['eval_prompt']
    # generate the chapter title based on the given chapter in the prompt 
    resp = llm_judge_json_evaluations(model_id, prompt)
    resp['original_title'] = row['original_title']
    resp['file_name'] = row['file_name']
    # calculate the input and output token price for all of the calls
    resp['input_token_price'] = (resp['prompt_token_count']/1000) * model_info['input_tokens_pricing']
    logger.info(f"The price for {resp['prompt_token_count']} tokens for {model_id} for filename={row['file_name']} chapter={row['chapter_id']} is {resp['input_token_price']}")
    resp['output_token_pricing'] = (resp['completion_token_count']/1000) * model_info['output_tokens_pricing']
    logger.info(f"The price for {resp['completion_token_count']} tokens for {model_id} for filename={row['file_name']} chapter={row['chapter_id']} is {resp['output_token_pricing']}")
    dir_path = os.path.join(config['dir']['model_eval_completions'], row['file_name'], model_id.replace(":", "-"))
    os.makedirs(dir_path, exist_ok=True)
    fpath = os.path.join(dir_path, f"model_evaluation_{row['chapter_id']}.json")
    logger.info(f"writing response={resp} to {fpath}")
    Path(fpath).write_text(json.dumps(resp, default=str, indent=2))
    logger.info(f"response {i}: {resp}")
    return resp

@ray.remote
def async_get_inference(i: int, row: Dict, total: int, model_info: Dict) -> Dict:
    logging.basicConfig(format='[%(asctime)s] p%(process)s {%(filename)s:%(lineno)d} %(levelname)s - %(message)s', level=logging.INFO)
    logger = logging.getLogger(__name__)
    return get_inference(i, row, total, model_info)

# %%
model_eval_df = json.loads(model_eval_df.to_json(orient='records'))
n: int = config['parallel_inference_count']
from typing import List
resp_list: List = []
model_list = config['eval_model_info']
st = time.perf_counter()
logger.info(f"------ running inference for {model_list.get('model')} -----")
list_of_lists = [model_eval_df[i * n:(i + 1) * n] for i in range((len(model_eval_df) + n - 1) // n )]
logger.info(f"split input list of size {len(model_eval_df)} into {len(list_of_lists)} lists")
for idx, l in enumerate(list_of_lists):
    logger.info(f"getting inference for list {idx+1}/{len(list_of_lists)}, size of list={len(l)} ")
    resp_list.extend(ray.get([async_get_inference.remote(i+1, e, len(l), model_list) for i, e in enumerate(l)]))
elapsed_time = time.perf_counter() - st
logger.info(f"------ model={model_list.get('model')} completed in {elapsed_time} ------ ")
# Out:
# [2024-06-01 17:14:37,647] p163 {161412846.py:7} INFO - ------ running inference for anthropic.claude-3-sonnet-20240229-v1:0 -----
# [2024-06-01 17:14:37,648] p163 {161412846.py:9} INFO - split input list of size 6 into 1 lists
# [2024-06-01 17:14:37,648] p163 {161412846.py:11} INFO - getting inference for list 1/1, size of list=6
# (async_get_inference pid=197) [2024-06-01 17:14:39,332] p197 {3857863317.py:5} INFO - row 6/6, prompt_template=eval_template.txt, model_id=anthropic.claude-3-sonnet-20240229-v1:0
# (async_get_inference pid=197) [2024-06-01 17:14:39,336] p197 {2625041246.py:29} INFO - Invoking bedrock/anthropic.claude-3-sonnet-20240229-v1:0......
# (async_get_inference pid=199) [2024-06-01 17:14:39,349] p199 {credentials.py:1278} INFO - Found credentials in shared credentials file: ~/.aws/credentials
# (async_get_inference pid=197) 17:14:39 - LiteLLM:INFO: utils.py:1133 -
# (async_get_inference pid=197) Request Sent from LiteLLM:
# (async_get_inference pid=197)
# (async_get_inference pid=197)             response = client.invoke_model(
# (async_get_inference pid=197)                 body={"messages": [{"role": "user", "content": [{"type": "text", "text": "Human: here is a transcript from a meeting in the <chapter></chapter> tag followed by chapter titles generated by different models.\nYour task is to select the title that best captures the content and meaning of the chapter in 1 to 4 words.\nPut the selected title, model name and explanation for selecting the title and not selecting other titles in a JSON as within 3 elements: \"best_match_title\", \"selected_model\", and \"explanation\".\nYour explanation should include both model name and title so that it is simple to understand which title was generated by which model and why it was or was not selected.\n\n<chapter>\n1015 \"Dr. E\" (1234567890)\n10:04:10.100 --> 10:04:16.400\nTake the concept of antimatter, for instance. It was purely theoretical until we found ways to produce and study it.\n\n1016 \"Dr. M\" (2345678901)\n10:04:16.400 --> 10:04:22.700\nAnd now we're harnessing antimatter for medical applications like proton therapy and advanced imaging techniques.\n\n1017 \"Dr. S\" (3456789012)\n10:04:22.700 --> 10:04:29.000\nNot to mention the potential for antimatter-based propulsion systems, which could revolutionize space exploration.\n\n1018 \"Dr. D\" (4567890123)\n10:04:29.000 --> 10:04:35.300\nAh yes, the dream of achieving faster-than-light travel. But we'd need to overcome some significant hurdles first.\n</chapter>\n\n<model_x>\nAntimatter and Its Potential Applications\n</model_x>\n\n\n<amazon.titan-text-express-v1>\nAntimatter in Medicine and Space Exploration\n</amazon.titan-text-express-v1>\n\n\n<anthropic.claude-3-haiku-20240307-v1:0>\nAntimatter's Scientific Potential\n</anthropic.claude-3-haiku-20240307-v1:0>\n\n\n<anthropic.claude-3-sonnet-20240229-v1:0>\nAntimatter Applications\n</anthropic.claude-3-sonnet-20240229-v1:0>\n\n\n<meta.llama3-70b-instruct-v1:0>\nAntimatter Applications\n</meta.llama3-70b-instruct-v1:0>\n\n\n<meta.llama3-8b-instruct-v1:0>\nAntimatter Applications\n</meta.llama3-8b-instruct-v1:0>\n\n\n<mistral.mistral-7b-instruct-v0:2>\nAntimatter Applications\n</mistral.mistral-7b-instruct-v0:2>\n\n\n<mistral.mixtral-8x7b-instruct-v0:1>\nAntimatter Applications\n</mistral.mixtral-8x7b-instruct-v0:1>\n\n\nAssistant: Here is the response in json:\n"}]}], "temperature": 0.1, "max_tokens": 500, "anthropic_version": "bedrock-2023-05-31"},
# (async_get_inference pid=197)                 modelId=anthropic.claude-3-sonnet-20240229-v1:0,
# (async_get_inference pid=197)                 accept=accept,
# (async_get_inference pid=197)                 contentType=contentType
# (async_get_inference pid=197)             )
# (async_get_inference pid=197)
# (async_get_inference pid=197)
# (async_get_inference pid=197) [2024-06-01 17:14:39,471] p197 {utils.py:1133} INFO -
# (async_get_inference pid=197) Request Sent from LiteLLM:
# (async_get_inference pid=197)
# (async_get_inference pid=197)             response = client.invoke_model(
# (async_get_inference pid=197)                 body={"messages": [{"role": "user", "content": [{"type": "text", "text": "Human: here is a transcript from a meeting in the <chapter></chapter> tag followed by chapter titles generated by different models.\nYour task is to select the title that best captures the content and meaning of the chapter in 1 to 4 words.\nPut the selected title, model name and explanation for selecting the title and not selecting other titles in a JSON as within 3 elements: \"best_match_title\", \"selected_model\", and \"explanation\".\nYour explanation should include both model name and title so that it is simple to understand which title was generated by which model and why it was or was not selected.\n\n<chapter>\n1015 \"Dr. E\" (1234567890)\n10:04:10.100 --> 10:04:16.400\nTake the concept of antimatter, for instance. It was purely theoretical until we found ways to produce and study it.\n\n1016 \"Dr. M\" (2345678901)\n10:04:16.400 --> 10:04:22.700\nAnd now we're harnessing antimatter for medical applications like proton therapy and advanced imaging techniques.\n\n1017 \"Dr. S\" (3456789012)\n10:04:22.700 --> 10:04:29.000\nNot to mention the potential for antimatter-based propulsion systems, which could revolutionize space exploration.\n\n1018 \"Dr. D\" (4567890123)\n10:04:29.000 --> 10:04:35.300\nAh yes, the dream of achieving faster-than-light travel. But we'd need to overcome some significant hurdles first.\n</chapter>\n\n<model_x>\nAntimatter and Its Potential Applications\n</model_x>\n\n\n<amazon.titan-text-express-v1>\nAntimatter in Medicine and Space Exploration\n</amazon.titan-text-express-v1>\n\n\n<anthropic.claude-3-haiku-20240307-v1:0>\nAntimatter's Scientific Potential\n</anthropic.claude-3-haiku-20240307-v1:0>\n\n\n<anthropic.claude-3-sonnet-20240229-v1:0>\nAntimatter Applications\n</anthropic.claude-3-sonnet-20240229-v1:0>\n\n\n<meta.llama3-70b-instruct-v1:0>\nAntimatter Applications\n</meta.llama3-70b-instruct-v1:0>\n\n\n<meta.llama3-8b-instruct-v1:0>\nAntimatter Applications\n</meta.llama3-8b-instruct-v1:0>\n\n\n<mistral.mistral-7b-instruct-v0:2>\nAntimatter Applications\n</mistral.mistral-7b-instruct-v0:2>\n\n\n<mistral.mixtral-8x7b-instruct-v0:1>\nAntimatter Applications\n</mistral.mixtral-8x7b-instruct-v0:1>\n\n\nAssistant: Here is the response in json:\n"}]}], "temperature": 0.1, "max_tokens": 500, "anthropic_version": "bedrock-2023-05-31"},
# (async_get_inference pid=197)                 modelId=anthropic.claude-3-sonnet-20240229-v1:0,
# (async_get_inference pid=197)                 accept=accept,
# (async_get_inference pid=197)                 contentType=contentType
# (async_get_inference pid=197)             )
# (async_get_inference pid=197)
# (async_get_inference pid=197)
# (async_get_inference pid=199)                 body={"messages": [{"role": "user", "content": [{"type": "text", "text": "Human: here is a transcript from a meeting in the <chapter></chapter> tag followed by chapter titles generated by different models.\nYour task is to select the title that best captures the content and meaning of the chapter in 1 to 4 words.\nPut the selected title, model name and explanation for selecting the title and not selecting other titles in a JSON as within 3 elements: \"best_match_title\", \"selected_model\", and \"explanation\".\nYour explanation should include both model name and title so that it is simple to understand which title was generated by which model and why it was or was not selected.\n\n<chapter>\n1006 \"Dr. D\" (4567890123)\n10:03:13.400 --> 10:03:19.700\nPrecisely. Without empirical data to support these theories, they remain highly speculative at this stage.\n\n1007 \"Dr. E\" (1234567890)\n10:03:19.700 --> 10:03:26.000\nPerhaps the answers lie in dimensions beyond our current understanding of space-time.\n\n1008 \"Dr. M\" (2345678901)\n10:03:26.000 --> 10:03:32.300\nAh, the mystical world of higher dimensions. That's where things really start to bend our minds.\n\n1009 \"Dr. S\" (3456789012)\n10:03:32.300 --> 10:03:38.600\nAgreed. The notion of a multidimensional universe is both fascinating and perplexing.\n\n1010 \"Dr. D\" (4567890123)\n10:03:38.600 --> 10:03:44.900\nIt's a tantalizing concept, but one that may forever elude our observational capabilities.\n</chapter>\n\n<model_x>\nExploring Higher Dimensions and the Fabric of Reality\n</model_x>\n\n\n<amazon.titan-text-express-v1>\nHigher Dimensions\n</amazon.titan-text-express-v1>\n\n\n<anthropic.claude-3-haiku-20240307-v1:0>\nMultidimensional Universe Theories\n</anthropic.claude-3-haiku-20240307-v1:0>\n\n\n<anthropic.claude-3-sonnet-20240229-v1:0>\nDimensions Beyond Space-Time\n</anthropic.claude-3-sonnet-20240229-v1:0>\n\n\n<meta.llama3-70b-instruct-v1:0>\nHigher Dimensions\n</meta.llama3-70b-instruct-v1:0>\n\n\n<meta.llama3-8b-instruct-v1:0>\nHigher Dimensions\n</meta.llama3-8b-instruct-v1:0>\n\n\n<mistral.mistral-7b-instruct-v0:2>\nHigher Dimensions Debate\n</mistral.mistral-7b-instruct-v0:2>\n\n\n<mistral.mixtral-8x7b-instruct-v0:1>\nHigher Dimensions\n</mistral.mixtral-8x7b-instruct-v0:1>\n\n\nAssistant: Here is the response in json:\n"}]}], "temperature": 0.1, "max_tokens": 500, "anthropic_version": "bedrock-2023-05-31"},
# (async_get_inference pid=199)                 body={"messages": [{"role": "user", "content": [{"type": "text", "text": "Human: here is a transcript from a meeting in the <chapter></chapter> tag followed by chapter titles generated by different models.\nYour task is to select the title that best captures the content and meaning of the chapter in 1 to 4 words.\nPut the selected title, model name and explanation for selecting the title and not selecting other titles in a JSON as within 3 elements: \"best_match_title\", \"selected_model\", and \"explanation\".\nYour explanation should include both model name and title so that it is simple to understand which title was generated by which model and why it was or was not selected.\n\n<chapter>\n1006 \"Dr. D\" (4567890123)\n10:03:13.400 --> 10:03:19.700\nPrecisely. Without empirical data to support these theories, they remain highly speculative at this stage.\n\n1007 \"Dr. E\" (1234567890)\n10:03:19.700 --> 10:03:26.000\nPerhaps the answers lie in dimensions beyond our current understanding of space-time.\n\n1008 \"Dr. M\" (2345678901)\n10:03:26.000 --> 10:03:32.300\nAh, the mystical world of higher dimensions. That's where things really start to bend our minds.\n\n1009 \"Dr. S\" (3456789012)\n10:03:32.300 --> 10:03:38.600\nAgreed. The notion of a multidimensional universe is both fascinating and perplexing.\n\n1010 \"Dr. D\" (4567890123)\n10:03:38.600 --> 10:03:44.900\nIt's a tantalizing concept, but one that may forever elude our observational capabilities.\n</chapter>\n\n<model_x>\nExploring Higher Dimensions and the Fabric of Reality\n</model_x>\n\n\n<amazon.titan-text-express-v1>\nHigher Dimensions\n</amazon.titan-text-express-v1>\n\n\n<anthropic.claude-3-haiku-20240307-v1:0>\nMultidimensional Universe Theories\n</anthropic.claude-3-haiku-20240307-v1:0>\n\n\n<anthropic.claude-3-sonnet-20240229-v1:0>\nDimensions Beyond Space-Time\n</anthropic.claude-3-sonnet-20240229-v1:0>\n\n\n<meta.llama3-70b-instruct-v1:0>\nHigher Dimensions\n</meta.llama3-70b-instruct-v1:0>\n\n\n<meta.llama3-8b-instruct-v1:0>\nHigher Dimensions\n</meta.llama3-8b-instruct-v1:0>\n\n\n<mistral.mistral-7b-instruct-v0:2>\nHigher Dimensions Debate\n</mistral.mistral-7b-instruct-v0:2>\n\n\n<mistral.mixtral-8x7b-instruct-v0:1>\nHigher Dimensions\n</mistral.mixtral-8x7b-instruct-v0:1>\n\n\nAssistant: Here is the response in json:\n"}]}], "temperature": 0.1, "max_tokens": 500, "anthropic_version": "bedrock-2023-05-31"},
# (async_get_inference pid=196)                 body={"messages": [{"role": "user", "content": [{"type": "text", "text": "Human: here is a transcript from a meeting in the <chapter></chapter> tag followed by chapter titles generated by different models.\nYour task is to select the title that best captures the content and meaning of the chapter in 1 to 4 words.\nPut the selected title, model name and explanation for selecting the title and not selecting other titles in a JSON as within 3 elements: \"best_match_title\", \"selected_model\", and \"explanation\".\nYour explanation should include both model name and title so that it is simple to understand which title was generated by which model and why it was or was not selected.\n\n<chapter>\n1001 \"Dr. S\" (3456789012)\n10:02:42.520 --> 10:02:48.200\nSpeaking of pushing boundaries, have you all considered the potential implications of quantum gravity on our current models?\n\n1002 \"Dr. D\" (4567890123)\n10:02:48.200 --> 10:02:54.600\nAh, the elusive theory of everything. That's been a Holy Grail for physicists ever since Einstein's time.\n\n1003 \"Dr. E\" (1234567890)\n10:02:54.600 --> 10:03:00.900\nQuantum gravity could potentially reconcile the disparities between general relativity and quantum mechanics.\n\n1004 \"Dr. M\" (2345678901)\n10:03:00.900 --> 10:03:07.100\nBut the mathematical complexities involved are mind-boggling. String theory is one approach, but it's far from complete.\n\n1005 \"Dr. S\" (3456789012)\n10:03:07.100 --> 10:03:13.400\nWhat about loop quantum gravity? That's another promising avenue, although the experimental verification is lacking.\n</chapter>\n\n<model_x>\nThe Quest for a Theory of Quantum Gravity\n</model_x>\n\n\n<amazon.titan-text-express-v1>\nExploring Quantum Gravity\n</amazon.titan-text-express-v1>\n\n\n<anthropic.claude-3-haiku-20240307-v1:0>\nQuantum Gravity Theories\n</anthropic.claude-3-haiku-20240307-v1:0>\n\n\n<anthropic.claude-3-sonnet-20240229-v1:0>\nQuantum Gravity Discussion\n</anthropic.claude-3-sonnet-20240229-v1:0>\n\n\n<meta.llama3-70b-instruct-v1:0>\nQuantum Gravity Implications\n</meta.llama3-70b-instruct-v1:0>\n\n\n<meta.llama3-8b-instruct-v1:0>\nQuantum Gravity Implications\n</meta.llama3-8b-instruct-v1:0>\n\n\n<mistral.mistral-7b-instruct-v0:2>\nQuantum Gravity Discussions\n</mistral.mistral-7b-instruct-v0:2>\n\n\n<mistral.mixtral-8x7b-instruct-v0:1>\nQuantum Gravity Theories\n</mistral.mixtral-8x7b-instruct-v0:1>\n\n\nAssistant: Here is the response in json:\n"}]}], "temperature": 0.1, "max_tokens": 500, "anthropic_version": "bedrock-2023-05-31"},
# (async_get_inference pid=196)                 body={"messages": [{"role": "user", "content": [{"type": "text", "text": "Human: here is a transcript from a meeting in the <chapter></chapter> tag followed by chapter titles generated by different models.\nYour task is to select the title that best captures the content and meaning of the chapter in 1 to 4 words.\nPut the selected title, model name and explanation for selecting the title and not selecting other titles in a JSON as within 3 elements: \"best_match_title\", \"selected_model\", and \"explanation\".\nYour explanation should include both model name and title so that it is simple to understand which title was generated by which model and why it was or was not selected.\n\n<chapter>\n1001 \"Dr. S\" (3456789012)\n10:02:42.520 --> 10:02:48.200\nSpeaking of pushing boundaries, have you all considered the potential implications of quantum gravity on our current models?\n\n1002 \"Dr. D\" (4567890123)\n10:02:48.200 --> 10:02:54.600\nAh, the elusive theory of everything. That's been a Holy Grail for physicists ever since Einstein's time.\n\n1003 \"Dr. E\" (1234567890)\n10:02:54.600 --> 10:03:00.900\nQuantum gravity could potentially reconcile the disparities between general relativity and quantum mechanics.\n\n1004 \"Dr. M\" (2345678901)\n10:03:00.900 --> 10:03:07.100\nBut the mathematical complexities involved are mind-boggling. String theory is one approach, but it's far from complete.\n\n1005 \"Dr. S\" (3456789012)\n10:03:07.100 --> 10:03:13.400\nWhat about loop quantum gravity? That's another promising avenue, although the experimental verification is lacking.\n</chapter>\n\n<model_x>\nThe Quest for a Theory of Quantum Gravity\n</model_x>\n\n\n<amazon.titan-text-express-v1>\nExploring Quantum Gravity\n</amazon.titan-text-express-v1>\n\n\n<anthropic.claude-3-haiku-20240307-v1:0>\nQuantum Gravity Theories\n</anthropic.claude-3-haiku-20240307-v1:0>\n\n\n<anthropic.claude-3-sonnet-20240229-v1:0>\nQuantum Gravity Discussion\n</anthropic.claude-3-sonnet-20240229-v1:0>\n\n\n<meta.llama3-70b-instruct-v1:0>\nQuantum Gravity Implications\n</meta.llama3-70b-instruct-v1:0>\n\n\n<meta.llama3-8b-instruct-v1:0>\nQuantum Gravity Implications\n</meta.llama3-8b-instruct-v1:0>\n\n\n<mistral.mistral-7b-instruct-v0:2>\nQuantum Gravity Discussions\n</mistral.mistral-7b-instruct-v0:2>\n\n\n<mistral.mixtral-8x7b-instruct-v0:1>\nQuantum Gravity Theories\n</mistral.mixtral-8x7b-instruct-v0:1>\n\n\nAssistant: Here is the response in json:\n"}]}], "temperature": 0.1, "max_tokens": 500, "anthropic_version": "bedrock-2023-05-31"},
# (async_get_inference pid=195)                 body={"messages": [{"role": "user", "content": [{"type": "text", "text": "Human: here is a transcript from a meeting in the <chapter></chapter> tag followed by chapter titles generated by different models.\nYour task is to select the title that best captures the content and meaning of the chapter in 1 to 4 words.\nPut the selected title, model name and explanation for selecting the title and not selecting other titles in a JSON as within 3 elements: \"best_match_title\", \"selected_model\", and \"explanation\".\nYour explanation should include both model name and title so that it is simple to understand which title was generated by which model and why it was or was not selected.\n\n<chapter>\n1011 \"Dr. E\" (1234567890)\n10:03:44.900 --> 10:03:51.200\nNot necessarily. With the advent of more powerful particle accelerators, we may be able to probe deeper into the fabric of reality.\n\n1012 \"Dr. M\" (2345678901)\n10:03:51.200 --> 10:03:57.500\nYou raise a fair point. The upcoming upgrades to the Large Hadron Collider could potentially reveal new insights.\n\n1013 \"Dr. S\" (3456789012)\n10:03:57.500 --> 10:04:03.800\nAnd let's not forget the importance of theoretical work. Sometimes the math leads us to unexpected places.\n\n1014 \"Dr. D\" (4567890123)\n10:04:03.800 --> 10:04:10.100\nAbsolutely. Some of the greatest breakthroughs in physics have come from pure thought experiments and mathematical models.\n</chapter>\n\n<model_x>\nThe Role of Theory and Experimentation in Physics\n</model_x>\n\n\n<amazon.titan-text-express-v1>\nExploring the Frontiers of Reality\n</amazon.titan-text-express-v1>\n\n\n<anthropic.claude-3-haiku-20240307-v1:0>\nProbing Particle Physics Frontiers\n</anthropic.claude-3-haiku-20240307-v1:0>\n\n\n<anthropic.claude-3-sonnet-20240229-v1:0>\nProbing Fundamental Physics\n</anthropic.claude-3-sonnet-20240229-v1:0>\n\n\n<meta.llama3-70b-instruct-v1:0>\nProbing Reality's Fabric\n</meta.llama3-70b-instruct-v1:0>\n\n\n<meta.llama3-8b-instruct-v1:0>\nParticle Accelerators\n</meta.llama3-8b-instruct-v1:0>\n\n\n<mistral.mistral-7b-instruct-v0:2>\nNew Insights\n</mistral.mistral-7b-instruct-v0:2>\n\n\n<mistral.mixtral-8x7b-instruct-v0:1>\nExploring Reality\n</mistral.mixtral-8x7b-instruct-v0:1>\n\n\nAssistant: Here is the response in json:\n"}]}], "temperature": 0.1, "max_tokens": 500, "anthropic_version": "bedrock-2023-05-31"},
# (async_get_inference pid=195)                 body={"messages": [{"role": "user", "content": [{"type": "text", "text": "Human: here is a transcript from a meeting in the <chapter></chapter> tag followed by chapter titles generated by different models.\nYour task is to select the title that best captures the content and meaning of the chapter in 1 to 4 words.\nPut the selected title, model name and explanation for selecting the title and not selecting other titles in a JSON as within 3 elements: \"best_match_title\", \"selected_model\", and \"explanation\".\nYour explanation should include both model name and title so that it is simple to understand which title was generated by which model and why it was or was not selected.\n\n<chapter>\n1011 \"Dr. E\" (1234567890)\n10:03:44.900 --> 10:03:51.200\nNot necessarily. With the advent of more powerful particle accelerators, we may be able to probe deeper into the fabric of reality.\n\n1012 \"Dr. M\" (2345678901)\n10:03:51.200 --> 10:03:57.500\nYou raise a fair point. The upcoming upgrades to the Large Hadron Collider could potentially reveal new insights.\n\n1013 \"Dr. S\" (3456789012)\n10:03:57.500 --> 10:04:03.800\nAnd let's not forget the importance of theoretical work. Sometimes the math leads us to unexpected places.\n\n1014 \"Dr. D\" (4567890123)\n10:04:03.800 --> 10:04:10.100\nAbsolutely. Some of the greatest breakthroughs in physics have come from pure thought experiments and mathematical models.\n</chapter>\n\n<model_x>\nThe Role of Theory and Experimentation in Physics\n</model_x>\n\n\n<amazon.titan-text-express-v1>\nExploring the Frontiers of Reality\n</amazon.titan-text-express-v1>\n\n\n<anthropic.claude-3-haiku-20240307-v1:0>\nProbing Particle Physics Frontiers\n</anthropic.claude-3-haiku-20240307-v1:0>\n\n\n<anthropic.claude-3-sonnet-20240229-v1:0>\nProbing Fundamental Physics\n</anthropic.claude-3-sonnet-20240229-v1:0>\n\n\n<meta.llama3-70b-instruct-v1:0>\nProbing Reality's Fabric\n</meta.llama3-70b-instruct-v1:0>\n\n\n<meta.llama3-8b-instruct-v1:0>\nParticle Accelerators\n</meta.llama3-8b-instruct-v1:0>\n\n\n<mistral.mistral-7b-instruct-v0:2>\nNew Insights\n</mistral.mistral-7b-instruct-v0:2>\n\n\n<mistral.mixtral-8x7b-instruct-v0:1>\nExploring Reality\n</mistral.mixtral-8x7b-instruct-v0:1>\n\n\nAssistant: Here is the response in json:\n"}]}], "temperature": 0.1, "max_tokens": 500, "anthropic_version": "bedrock-2023-05-31"},
# (async_get_inference pid=201)                 body={"messages": [{"role": "user", "content": [{"type": "text", "text": "Human: here is a transcript from a meeting in the <chapter></chapter> tag followed by chapter titles generated by different models.\nYour task is to select the title that best captures the content and meaning of the chapter in 1 to 4 words.\nPut the selected title, model name and explanation for selecting the title and not selecting other titles in a JSON as within 3 elements: \"best_match_title\", \"selected_model\", and \"explanation\".\nYour explanation should include both model name and title so that it is simple to understand which title was generated by which model and why it was or was not selected.\n\n<chapter>\n996 \"Dr. M\" (2345678901)\n10:02:15.340 --> 10:02:20.720\nThe upcoming run at the Tevatron should provide us with even more data to analyze.\n\n997 \"Dr. S\" (3456789012)\n10:02:20.720 --> 10:02:26.500\nDon't forget about the proposed muon collider project. That could open up new frontiers in high-energy physics.\n\n998 \"Dr. D\" (4567890123)\n10:02:26.500 --> 10:02:31.870\nTrue, but the funding challenges for such a large-scale endeavor are substantial.\n\n999 \"Dr. E\" (1234567890)\n10:02:31.870 --> 10:02:37.140\nRegardless, the future of particle physics is full of exciting possibilities.\n\n1000 \"Dr. M\" (2345678901)\n10:02:37.140 --> 10:02:42.520\nIndeed. As long as we continue to ask questions and push the boundaries of our knowledge, we'll make groundbreaking discoveries.\n</chapter>\n\n<model_x>\nExploring Future Frontiers in Particle Physics\n</model_x>\n\n\n<amazon.titan-text-express-v1>\nParticle Physics Prospects\n</amazon.titan-text-express-v1>\n\n\n<anthropic.claude-3-haiku-20240307-v1:0>\nParticle Physics Frontiers\n</anthropic.claude-3-haiku-20240307-v1:0>\n\n\n<anthropic.claude-3-sonnet-20240229-v1:0>\nFuture of Particle Physics\n</anthropic.claude-3-sonnet-20240229-v1:0>\n\n\n<meta.llama3-70b-instruct-v1:0>\nFuture of Physics\n</meta.llama3-70b-instruct-v1:0>\n\n\n<meta.llama3-8b-instruct-v1:0>\nFuture of Particle Physics\n</meta.llama3-8b-instruct-v1:0>\n\n\n<mistral.mistral-7b-instruct-v0:2>\nFuture Physics Projects\n</mistral.mistral-7b-instruct-v0:2>\n\n\n<mistral.mixtral-8x7b-instruct-v0:1>\nFuture of Particle Physics\n</mistral.mixtral-8x7b-instruct-v0:1>\n\n\nAssistant: Here is the response in json:\n"}]}], "temperature": 0.1, "max_tokens": 500, "anthropic_version": "bedrock-2023-05-31"},
# (async_get_inference pid=201)                 body={"messages": [{"role": "user", "content": [{"type": "text", "text": "Human: here is a transcript from a meeting in the <chapter></chapter> tag followed by chapter titles generated by different models.\nYour task is to select the title that best captures the content and meaning of the chapter in 1 to 4 words.\nPut the selected title, model name and explanation for selecting the title and not selecting other titles in a JSON as within 3 elements: \"best_match_title\", \"selected_model\", and \"explanation\".\nYour explanation should include both model name and title so that it is simple to understand which title was generated by which model and why it was or was not selected.\n\n<chapter>\n996 \"Dr. M\" (2345678901)\n10:02:15.340 --> 10:02:20.720\nThe upcoming run at the Tevatron should provide us with even more data to analyze.\n\n997 \"Dr. S\" (3456789012)\n10:02:20.720 --> 10:02:26.500\nDon't forget about the proposed muon collider project. That could open up new frontiers in high-energy physics.\n\n998 \"Dr. D\" (4567890123)\n10:02:26.500 --> 10:02:31.870\nTrue, but the funding challenges for such a large-scale endeavor are substantial.\n\n999 \"Dr. E\" (1234567890)\n10:02:31.870 --> 10:02:37.140\nRegardless, the future of particle physics is full of exciting possibilities.\n\n1000 \"Dr. M\" (2345678901)\n10:02:37.140 --> 10:02:42.520\nIndeed. As long as we continue to ask questions and push the boundaries of our knowledge, we'll make groundbreaking discoveries.\n</chapter>\n\n<model_x>\nExploring Future Frontiers in Particle Physics\n</model_x>\n\n\n<amazon.titan-text-express-v1>\nParticle Physics Prospects\n</amazon.titan-text-express-v1>\n\n\n<anthropic.claude-3-haiku-20240307-v1:0>\nParticle Physics Frontiers\n</anthropic.claude-3-haiku-20240307-v1:0>\n\n\n<anthropic.claude-3-sonnet-20240229-v1:0>\nFuture of Particle Physics\n</anthropic.claude-3-sonnet-20240229-v1:0>\n\n\n<meta.llama3-70b-instruct-v1:0>\nFuture of Physics\n</meta.llama3-70b-instruct-v1:0>\n\n\n<meta.llama3-8b-instruct-v1:0>\nFuture of Particle Physics\n</meta.llama3-8b-instruct-v1:0>\n\n\n<mistral.mistral-7b-instruct-v0:2>\nFuture Physics Projects\n</mistral.mistral-7b-instruct-v0:2>\n\n\n<mistral.mixtral-8x7b-instruct-v0:1>\nFuture of Particle Physics\n</mistral.mixtral-8x7b-instruct-v0:1>\n\n\nAssistant: Here is the response in json:\n"}]}], "temperature": 0.1, "max_tokens": 500, "anthropic_version": "bedrock-2023-05-31"},
# (async_get_inference pid=198)                 body={"messages": [{"role": "user", "content": [{"type": "text", "text": "Human: here is a transcript from a meeting in the <chapter></chapter> tag followed by chapter titles generated by different models.\nYour task is to select the title that best captures the content and meaning of the chapter in 1 to 4 words.\nPut the selected title, model name and explanation for selecting the title and not selecting other titles in a JSON as within 3 elements: \"best_match_title\", \"selected_model\", and \"explanation\".\nYour explanation should include both model name and title so that it is simple to understand which title was generated by which model and why it was or was not selected.\n\n<chapter>\n1 \"Dr. E\" (1234567890)\n00:00:00.000 --> 00:00:05.340\nHave you all seen the latest results from the Large Hadron Collider? The data on the Higgs boson is quite fascinating.\n\n2 \"Dr. M\" (2345678901)\n00:00:05.340 --> 00:00:10.720\nYes, I've been studying the particle trajectories closely. The decay patterns are consistent with our theoretical models.\n\n3 \"Dr. S\" (3456789012)\n00:00:10.720 --> 00:00:16.500\nI'm more interested in the potential applications of these findings. Could we harness the Higgs field for energy production?\n\n4 \"Dr. D\" (4567890123)\n00:00:16.500 --> 00:00:21.870\nThat's an intriguing idea, but we'd need to overcome some significant technical hurdles first.\n\n5 \"Dr. E\" (1234567890)\n00:00:21.870 --> 00:00:27.140\nAbsolutely. Have you considered the implications of these findings on our understanding of dark matter?\n</chapter>\n\n<model_x>\nDiscussing the Higgs Boson and Its Implications\n</model_x>\n\n\n<amazon.titan-text-express-v1>\nHiggs Boson and its Implications\n</amazon.titan-text-express-v1>\n\n\n<anthropic.claude-3-haiku-20240307-v1:0>\nHiggs Boson Particle Discoveries\n</anthropic.claude-3-haiku-20240307-v1:0>\n\n\n<anthropic.claude-3-sonnet-20240229-v1:0>\nHiggs Boson Discussion\n</anthropic.claude-3-sonnet-20240229-v1:0>\n\n\n<meta.llama3-70b-instruct-v1:0>\nHiggs Boson Implications\n</meta.llama3-70b-instruct-v1:0>\n\n\n<meta.llama3-8b-instruct-v1:0>\nHiggs Boson Discussion\n</meta.llama3-8b-instruct-v1:0>\n\n\n<mistral.mistral-7b-instruct-v0:2>\nHiggs Applications\n</mistral.mistral-7b-instruct-v0:2>\n\n\n<mistral.mixtral-8x7b-instruct-v0:1>\nHiggs Boson Discussion\n</mistral.mixtral-8x7b-instruct-v0:1>\n\n\nAssistant: Here is the response in json:\n"}]}], "temperature": 0.1, "max_tokens": 500, "anthropic_version": "bedrock-2023-05-31"},
# (async_get_inference pid=198)                 body={"messages": [{"role": "user", "content": [{"type": "text", "text": "Human: here is a transcript from a meeting in the <chapter></chapter> tag followed by chapter titles generated by different models.\nYour task is to select the title that best captures the content and meaning of the chapter in 1 to 4 words.\nPut the selected title, model name and explanation for selecting the title and not selecting other titles in a JSON as within 3 elements: \"best_match_title\", \"selected_model\", and \"explanation\".\nYour explanation should include both model name and title so that it is simple to understand which title was generated by which model and why it was or was not selected.\n\n<chapter>\n1 \"Dr. E\" (1234567890)\n00:00:00.000 --> 00:00:05.340\nHave you all seen the latest results from the Large Hadron Collider? The data on the Higgs boson is quite fascinating.\n\n2 \"Dr. M\" (2345678901)\n00:00:05.340 --> 00:00:10.720\nYes, I've been studying the particle trajectories closely. The decay patterns are consistent with our theoretical models.\n\n3 \"Dr. S\" (3456789012)\n00:00:10.720 --> 00:00:16.500\nI'm more interested in the potential applications of these findings. Could we harness the Higgs field for energy production?\n\n4 \"Dr. D\" (4567890123)\n00:00:16.500 --> 00:00:21.870\nThat's an intriguing idea, but we'd need to overcome some significant technical hurdles first.\n\n5 \"Dr. E\" (1234567890)\n00:00:21.870 --> 00:00:27.140\nAbsolutely. Have you considered the implications of these findings on our understanding of dark matter?\n</chapter>\n\n<model_x>\nDiscussing the Higgs Boson and Its Implications\n</model_x>\n\n\n<amazon.titan-text-express-v1>\nHiggs Boson and its Implications\n</amazon.titan-text-express-v1>\n\n\n<anthropic.claude-3-haiku-20240307-v1:0>\nHiggs Boson Particle Discoveries\n</anthropic.claude-3-haiku-20240307-v1:0>\n\n\n<anthropic.claude-3-sonnet-20240229-v1:0>\nHiggs Boson Discussion\n</anthropic.claude-3-sonnet-20240229-v1:0>\n\n\n<meta.llama3-70b-instruct-v1:0>\nHiggs Boson Implications\n</meta.llama3-70b-instruct-v1:0>\n\n\n<meta.llama3-8b-instruct-v1:0>\nHiggs Boson Discussion\n</meta.llama3-8b-instruct-v1:0>\n\n\n<mistral.mistral-7b-instruct-v0:2>\nHiggs Applications\n</mistral.mistral-7b-instruct-v0:2>\n\n\n<mistral.mixtral-8x7b-instruct-v0:1>\nHiggs Boson Discussion\n</mistral.mixtral-8x7b-instruct-v0:1>\n\n\nAssistant: Here is the response in json:\n"}]}], "temperature": 0.1, "max_tokens": 500, "anthropic_version": "bedrock-2023-05-31"},
# (async_get_inference pid=197) row={'file_name': 'particle_physics_meeting.json', 'chapter_id': 5, 'chapter_text': '1015 "Dr. E" (1234567890)\n10:04:10.100 --> 10:04:16.400\nTake the concept of antimatter, for instance. It was purely theoretical until we found ways to produce and study it.\n\n1016 "Dr. M" (2345678901)\n10:04:16.400 --> 10:04:22.700\nAnd now we\'re harnessing antimatter for medical applications like proton therapy and advanced imaging techniques.\n\n1017 "Dr. S" (3456789012)\n10:04:22.700 --> 10:04:29.000\nNot to mention the potential for antimatter-based propulsion systems, which could revolutionize space exploration.\n\n1018 "Dr. D" (4567890123)\n10:04:29.000 --> 10:04:35.300\nAh yes, the dream of achieving faster-than-light travel. But we\'d need to overcome some significant hurdles first.', 'original_title': 'Antimatter and Its Potential Applications', 'amazon.titan-text-express-v1_title': 'Antimatter in Medicine and Space Exploration', 'anthropic.claude-3-haiku-20240307-v1:0_title': "Antimatter's Scientific Potential", 'anthropic.claude-3-sonnet-20240229-v1:0_title': 'Antimatter Applications', 'meta.llama3-70b-instruct-v1:0_title': 'Antimatter Applications', 'meta.llama3-8b-instruct-v1:0_title': 'Antimatter Applications', 'mistral.mistral-7b-instruct-v0:2_title': 'Antimatter Applications', 'mistral.mixtral-8x7b-instruct-v0:1_title': 'Antimatter Applications', 'eval_prompt': 'Human: here is a transcript from a meeting in the <chapter></chapter> tag followed by chapter titles generated by different models.\nYour task is to select the title that best captures the content and meaning of the chapter in 1 to 4 words.\nPut the selected title, model name and explanation for selecting the title and not selecting other titles in a JSON as within 3 elements: "best_match_title", "selected_model", and "explanation".\nYour explanation should include both model name and title so that it is simple to understand which title was generated by which model and why it was or was not selected.\n\n<chapter>\n1015 "Dr. E" (1234567890)\n10:04:10.100 --> 10:04:16.400\nTake the concept of antimatter, for instance. It was purely theoretical until we found ways to produce and study it.\n\n1016 "Dr. M" (2345678901)\n10:04:16.400 --> 10:04:22.700\nAnd now we\'re harnessing antimatter for medical applications like proton therapy and advanced imaging techniques.\n\n1017 "Dr. S" (3456789012)\n10:04:22.700 --> 10:04:29.000\nNot to mention the potential for antimatter-based propulsion systems, which could revolutionize space exploration.\n\n1018 "Dr. D" (4567890123)\n10:04:29.000 --> 10:04:35.300\nAh yes, the dream of achieving faster-than-light travel. But we\'d need to overcome some significant hurdles first.\n</chapter>\n\n<model_x>\nAntimatter and Its Potential Applications\n</model_x>\n\n\n<amazon.titan-text-express-v1>\nAntimatter in Medicine and Space Exploration\n</amazon.titan-text-express-v1>\n\n\n<anthropic.claude-3-haiku-20240307-v1:0>\nAntimatter\'s Scientific Potential\n</anthropic.claude-3-haiku-20240307-v1:0>\n\n\n<anthropic.claude-3-sonnet-20240229-v1:0>\nAntimatter Applications\n</anthropic.claude-3-sonnet-20240229-v1:0>\n\n\n<meta.llama3-70b-instruct-v1:0>\nAntimatter Applications\n</meta.llama3-70b-instruct-v1:0>\n\n\n<meta.llama3-8b-instruct-v1:0>\nAntimatter Applications\n</meta.llama3-8b-instruct-v1:0>\n\n\n<mistral.mistral-7b-instruct-v0:2>\nAntimatter Applications\n</mistral.mistral-7b-instruct-v0:2>\n\n\n<mistral.mixtral-8x7b-instruct-v0:1>\nAntimatter Applications\n</mistral.mixtral-8x7b-instruct-v0:1>\n\n\nAssistant: Here is the response in json:\n'}
# (async_get_inference pid=195) row={'file_name': 'particle_physics_meeting.json', 'chapter_id': 4, 'chapter_text': '1011 "Dr. E" (1234567890)\n10:03:44.900 --> 10:03:51.200\nNot necessarily. With the advent of more powerful particle accelerators, we may be able to probe deeper into the fabric of reality.\n\n1012 "Dr. M" (2345678901)\n10:03:51.200 --> 10:03:57.500\nYou raise a fair point. The upcoming upgrades to the Large Hadron Collider could potentially reveal new insights.\n\n1013 "Dr. S" (3456789012)\n10:03:57.500 --> 10:04:03.800\nAnd let\'s not forget the importance of theoretical work. Sometimes the math leads us to unexpected places.\n\n1014 "Dr. D" (4567890123)\n10:04:03.800 --> 10:04:10.100\nAbsolutely. Some of the greatest breakthroughs in physics have come from pure thought experiments and mathematical models.', 'original_title': 'The Role of Theory and Experimentation in Physics', 'amazon.titan-text-express-v1_title': 'Exploring the Frontiers of Reality', 'anthropic.claude-3-haiku-20240307-v1:0_title': 'Probing Particle Physics Frontiers', 'anthropic.claude-3-sonnet-20240229-v1:0_title': 'Probing Fundamental Physics', 'meta.llama3-70b-instruct-v1:0_title': "Probing Reality's Fabric", 'meta.llama3-8b-instruct-v1:0_title': 'Particle Accelerators', 'mistral.mistral-7b-instruct-v0:2_title': 'New Insights', 'mistral.mixtral-8x7b-instruct-v0:1_title': 'Exploring Reality', 'eval_prompt': 'Human: here is a transcript from a meeting in the <chapter></chapter> tag followed by chapter titles generated by different models.\nYour task is to select the title that best captures the content and meaning of the chapter in 1 to 4 words.\nPut the selected title, model name and explanation for selecting the title and not selecting other titles in a JSON as within 3 elements: "best_match_title", "selected_model", and "explanation".\nYour explanation should include both model name and title so that it is simple to understand which title was generated by which model and why it was or was not selected.\n\n<chapter>\n1011 "Dr. E" (1234567890)\n10:03:44.900 --> 10:03:51.200\nNot necessarily. With the advent of more powerful particle accelerators, we may be able to probe deeper into the fabric of reality.\n\n1012 "Dr. M" (2345678901)\n10:03:51.200 --> 10:03:57.500\nYou raise a fair point. The upcoming upgrades to the Large Hadron Collider could potentially reveal new insights.\n\n1013 "Dr. S" (3456789012)\n10:03:57.500 --> 10:04:03.800\nAnd let\'s not forget the importance of theoretical work. Sometimes the math leads us to unexpected places.\n\n1014 "Dr. D" (4567890123)\n10:04:03.800 --> 10:04:10.100\nAbsolutely. Some of the greatest breakthroughs in physics have come from pure thought experiments and mathematical models.\n</chapter>\n\n<model_x>\nThe Role of Theory and Experimentation in Physics\n</model_x>\n\n\n<amazon.titan-text-express-v1>\nExploring the Frontiers of Reality\n</amazon.titan-text-express-v1>\n\n\n<anthropic.claude-3-haiku-20240307-v1:0>\nProbing Particle Physics Frontiers\n</anthropic.claude-3-haiku-20240307-v1:0>\n\n\n<anthropic.claude-3-sonnet-20240229-v1:0>\nProbing Fundamental Physics\n</anthropic.claude-3-sonnet-20240229-v1:0>\n\n\n<meta.llama3-70b-instruct-v1:0>\nProbing Reality\'s Fabric\n</meta.llama3-70b-instruct-v1:0>\n\n\n<meta.llama3-8b-instruct-v1:0>\nParticle Accelerators\n</meta.llama3-8b-instruct-v1:0>\n\n\n<mistral.mistral-7b-instruct-v0:2>\nNew Insights\n</mistral.mistral-7b-instruct-v0:2>\n\n\n<mistral.mixtral-8x7b-instruct-v0:1>\nExploring Reality\n</mistral.mixtral-8x7b-instruct-v0:1>\n\n\nAssistant: Here is the response in json:\n'}
# (async_get_inference pid=199) row={'file_name': 'particle_physics_meeting.json', 'chapter_id': 3, 'chapter_text': '1006 "Dr. D" (4567890123)\n10:03:13.400 --> 10:03:19.700\nPrecisely. Without empirical data to support these theories, they remain highly speculative at this stage.\n\n1007 "Dr. E" (1234567890)\n10:03:19.700 --> 10:03:26.000\nPerhaps the answers lie in dimensions beyond our current understanding of space-time.\n\n1008 "Dr. M" (2345678901)\n10:03:26.000 --> 10:03:32.300\nAh, the mystical world of higher dimensions. That\'s where things really start to bend our minds.\n\n1009 "Dr. S" (3456789012)\n10:03:32.300 --> 10:03:38.600\nAgreed. The notion of a multidimensional universe is both fascinating and perplexing.\n\n1010 "Dr. D" (4567890123)\n10:03:38.600 --> 10:03:44.900\nIt\'s a tantalizing concept, but one that may forever elude our observational capabilities.', 'original_title': 'Exploring Higher Dimensions and the Fabric of Reality', 'amazon.titan-text-express-v1_title': 'Higher Dimensions', 'anthropic.claude-3-haiku-20240307-v1:0_title': 'Multidimensional Universe Theories', 'anthropic.claude-3-sonnet-20240229-v1:0_title': 'Dimensions Beyond Space-Time', 'meta.llama3-70b-instruct-v1:0_title': 'Higher Dimensions', 'meta.llama3-8b-instruct-v1:0_title': 'Higher Dimensions', 'mistral.mistral-7b-instruct-v0:2_title': 'Higher Dimensions Debate', 'mistral.mixtral-8x7b-instruct-v0:1_title': 'Higher Dimensions', 'eval_prompt': 'Human: here is a transcript from a meeting in the <chapter></chapter> tag followed by chapter titles generated by different models.\nYour task is to select the title that best captures the content and meaning of the chapter in 1 to 4 words.\nPut the selected title, model name and explanation for selecting the title and not selecting other titles in a JSON as within 3 elements: "best_match_title", "selected_model", and "explanation".\nYour explanation should include both model name and title so that it is simple to understand which title was generated by which model and why it was or was not selected.\n\n<chapter>\n1006 "Dr. D" (4567890123)\n10:03:13.400 --> 10:03:19.700\nPrecisely. Without empirical data to support these theories, they remain highly speculative at this stage.\n\n1007 "Dr. E" (1234567890)\n10:03:19.700 --> 10:03:26.000\nPerhaps the answers lie in dimensions beyond our current understanding of space-time.\n\n1008 "Dr. M" (2345678901)\n10:03:26.000 --> 10:03:32.300\nAh, the mystical world of higher dimensions. That\'s where things really start to bend our minds.\n\n1009 "Dr. S" (3456789012)\n10:03:32.300 --> 10:03:38.600\nAgreed. The notion of a multidimensional universe is both fascinating and perplexing.\n\n1010 "Dr. D" (4567890123)\n10:03:38.600 --> 10:03:44.900\nIt\'s a tantalizing concept, but one that may forever elude our observational capabilities.\n</chapter>\n\n<model_x>\nExploring Higher Dimensions and the Fabric of Reality\n</model_x>\n\n\n<amazon.titan-text-express-v1>\nHigher Dimensions\n</amazon.titan-text-express-v1>\n\n\n<anthropic.claude-3-haiku-20240307-v1:0>\nMultidimensional Universe Theories\n</anthropic.claude-3-haiku-20240307-v1:0>\n\n\n<anthropic.claude-3-sonnet-20240229-v1:0>\nDimensions Beyond Space-Time\n</anthropic.claude-3-sonnet-20240229-v1:0>\n\n\n<meta.llama3-70b-instruct-v1:0>\nHigher Dimensions\n</meta.llama3-70b-instruct-v1:0>\n\n\n<meta.llama3-8b-instruct-v1:0>\nHigher Dimensions\n</meta.llama3-8b-instruct-v1:0>\n\n\n<mistral.mistral-7b-instruct-v0:2>\nHigher Dimensions Debate\n</mistral.mistral-7b-instruct-v0:2>\n\n\n<mistral.mixtral-8x7b-instruct-v0:1>\nHigher Dimensions\n</mistral.mixtral-8x7b-instruct-v0:1>\n\n\nAssistant: Here is the response in json:\n'}
# (async_get_inference pid=196) row={'file_name': 'particle_physics_meeting.json', 'chapter_id': 2, 'chapter_text': '1001 "Dr. S" (3456789012)\n10:02:42.520 --> 10:02:48.200\nSpeaking of pushing boundaries, have you all considered the potential implications of quantum gravity on our current models?\n\n1002 "Dr. D" (4567890123)\n10:02:48.200 --> 10:02:54.600\nAh, the elusive theory of everything. That\'s been a Holy Grail for physicists ever since Einstein\'s time.\n\n1003 "Dr. E" (1234567890)\n10:02:54.600 --> 10:03:00.900\nQuantum gravity could potentially reconcile the disparities between general relativity and quantum mechanics.\n\n1004 "Dr. M" (2345678901)\n10:03:00.900 --> 10:03:07.100\nBut the mathematical complexities involved are mind-boggling. String theory is one approach, but it\'s far from complete.\n\n1005 "Dr. S" (3456789012)\n10:03:07.100 --> 10:03:13.400\nWhat about loop quantum gravity? That\'s another promising avenue, although the experimental verification is lacking.', 'original_title': 'The Quest for a Theory of Quantum Gravity', 'amazon.titan-text-express-v1_title': 'Exploring Quantum Gravity', 'anthropic.claude-3-haiku-20240307-v1:0_title': 'Quantum Gravity Theories', 'anthropic.claude-3-sonnet-20240229-v1:0_title': 'Quantum Gravity Discussion', 'meta.llama3-70b-instruct-v1:0_title': 'Quantum Gravity Implications', 'meta.llama3-8b-instruct-v1:0_title': 'Quantum Gravity Implications', 'mistral.mistral-7b-instruct-v0:2_title': 'Quantum Gravity Discussions', 'mistral.mixtral-8x7b-instruct-v0:1_title': 'Quantum Gravity Theories', 'eval_prompt': 'Human: here is a transcript from a meeting in the <chapter></chapter> tag followed by chapter titles generated by different models.\nYour task is to select the title that best captures the content and meaning of the chapter in 1 to 4 words.\nPut the selected title, model name and explanation for selecting the title and not selecting other titles in a JSON as within 3 elements: "best_match_title", "selected_model", and "explanation".\nYour explanation should include both model name and title so that it is simple to understand which title was generated by which model and why it was or was not selected.\n\n<chapter>\n1001 "Dr. S" (3456789012)\n10:02:42.520 --> 10:02:48.200\nSpeaking of pushing boundaries, have you all considered the potential implications of quantum gravity on our current models?\n\n1002 "Dr. D" (4567890123)\n10:02:48.200 --> 10:02:54.600\nAh, the elusive theory of everything. That\'s been a Holy Grail for physicists ever since Einstein\'s time.\n\n1003 "Dr. E" (1234567890)\n10:02:54.600 --> 10:03:00.900\nQuantum gravity could potentially reconcile the disparities between general relativity and quantum mechanics.\n\n1004 "Dr. M" (2345678901)\n10:03:00.900 --> 10:03:07.100\nBut the mathematical complexities involved are mind-boggling. String theory is one approach, but it\'s far from complete.\n\n1005 "Dr. S" (3456789012)\n10:03:07.100 --> 10:03:13.400\nWhat about loop quantum gravity? That\'s another promising avenue, although the experimental verification is lacking.\n</chapter>\n\n<model_x>\nThe Quest for a Theory of Quantum Gravity\n</model_x>\n\n\n<amazon.titan-text-express-v1>\nExploring Quantum Gravity\n</amazon.titan-text-express-v1>\n\n\n<anthropic.claude-3-haiku-20240307-v1:0>\nQuantum Gravity Theories\n</anthropic.claude-3-haiku-20240307-v1:0>\n\n\n<anthropic.claude-3-sonnet-20240229-v1:0>\nQuantum Gravity Discussion\n</anthropic.claude-3-sonnet-20240229-v1:0>\n\n\n<meta.llama3-70b-instruct-v1:0>\nQuantum Gravity Implications\n</meta.llama3-70b-instruct-v1:0>\n\n\n<meta.llama3-8b-instruct-v1:0>\nQuantum Gravity Implications\n</meta.llama3-8b-instruct-v1:0>\n\n\n<mistral.mistral-7b-instruct-v0:2>\nQuantum Gravity Discussions\n</mistral.mistral-7b-instruct-v0:2>\n\n\n<mistral.mixtral-8x7b-instruct-v0:1>\nQuantum Gravity Theories\n</mistral.mixtral-8x7b-instruct-v0:1>\n\n\nAssistant: Here is the response in json:\n'}
# ...
# (async_get_inference pid=201) [2024-06-01 17:14:44,391] p201 {3857863317.py:23} INFO - response 2: {'exception': None, 'prompt': 'Human: here is a transcript from a meeting in the <chapter></chapter> tag followed by chapter titles generated by different models.\nYour task is to select the title that best captures the content and meaning of the chapter in 1 to 4 words.\nPut the selected title, model name and explanation for selecting the title and not selecting other titles in a JSON as within 3 elements: "best_match_title", "selected_model", and "explanation".\nYour explanation should include both model name and title so that it is simple to understand which title was generated by which model and why it was or was not selected.\n\n<chapter>\n996 "Dr. M" (2345678901)\n10:02:15.340 --> 10:02:20.720\nThe upcoming run at the Tevatron should provide us with even more data to analyze.\n\n997 "Dr. S" (3456789012)\n10:02:20.720 --> 10:02:26.500\nDon\'t forget about the proposed muon collider project. That could open up new frontiers in high-energy physics.\n\n998 "Dr. D" (4567890123)\n10:02:26.500 --> 10:02:31.870\nTrue, but the funding challenges for such a large-scale endeavor are substantial.\n\n999 "Dr. E" (1234567890)\n10:02:31.870 --> 10:02:37.140\nRegardless, the future of particle physics is full of exciting possibilities.\n\n1000 "Dr. M" (2345678901)\n10:02:37.140 --> 10:02:42.520\nIndeed. As long as we continue to ask questions and push the boundaries of our knowledge, we\'ll make groundbreaking discoveries.\n</chapter>\n\n<model_x>\nExploring Future Frontiers in Particle Physics\n</model_x>\n\n\n<amazon.titan-text-express-v1>\nParticle Physics Prospects\n</amazon.titan-text-express-v1>\n\n\n<anthropic.claude-3-haiku-20240307-v1:0>\nParticle Physics Frontiers\n</anthropic.claude-3-haiku-20240307-v1:0>\n\n\n<anthropic.claude-3-sonnet-20240229-v1:0>\nFuture of Particle Physics\n</anthropic.claude-3-sonnet-20240229-v1:0>\n\n\n<meta.llama3-70b-instruct-v1:0>\nFuture of Physics\n</meta.llama3-70b-instruct-v1:0>\n\n\n<meta.llama3-8b-instruct-v1:0>\nFuture of Particle Physics\n</meta.llama3-8b-instruct-v1:0>\n\n\n<mistral.mistral-7b-instruct-v0:2>\nFuture Physics Projects\n</mistral.mistral-7b-instruct-v0:2>\n\n\n<mistral.mixtral-8x7b-instruct-v0:1>\nFuture of Particle Physics\n</mistral.mixtral-8x7b-instruct-v0:1>\n\n\nAssistant: Here is the response in json:\n', 'completion': '{\n  "best_match_title": "Future of Particle Physics",\n  "selected_model": "anthropic.claude-3-sonnet-20240229-v1:0",\n  "explanation": "The title \'Future of Particle Physics\' generated by the anthropic.claude-3-sonnet-20240229-v1:0 model best captures the content and meaning of the chapter. The discussion in the transcript revolves around future projects and possibilities in the field of particle physics, such as the upcoming run at the Tevatron, the proposed muon collider project, and the general excitement about groundbreaking discoveries in the future. Other titles like \'Particle Physics Frontiers\' (anthropic.claude-3-haiku-20240307-v1:0) and \'Particle Physics Prospects\' (amazon.titan-text-express-v1) also capture the essence of the discussion but are not as concise and direct as \'Future of Particle Physics\'. Titles like \'Exploring Future Frontiers in Particle Physics\' (model_x) and \'Future Physics Projects\' (mistral.mistral-7b-instruct-v0:2) are too long and wordy, while \'Future of Physics\' (meta.llama3-70b-instruct-v1:0) is too broad and does not specifically mention particle physics."\n}', 'file_name': 'particle_physics_meeting.json', 'original_title': 'Exploring Future Frontiers in Particle Physics', 'completion_token_count': 316, 'prompt_token_count': 752, 'input_token_price': 0.002256, 'output_token_pricing': 0.00474, 'model_id': 'anthropic.claude-3-sonnet-20240229-v1:0'}
# (async_get_inference pid=198) [2024-06-01 17:14:39,339] p198 {3857863317.py:5} INFO - row 1/6, prompt_template=eval_template.txt, model_id=anthropic.claude-3-sonnet-20240229-v1:0 [repeated 5x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (async_get_inference pid=198) [2024-06-01 17:14:39,344] p198 {2625041246.py:29} INFO - Invoking bedrock/anthropic.claude-3-sonnet-20240229-v1:0...... [repeated 5x across cluster]
# (async_get_inference pid=197) [2024-06-01 17:14:39,351] p197 {credentials.py:1278} INFO - Found credentials in shared credentials file: ~/.aws/credentials [repeated 5x across cluster]
# [2024-06-01 17:14:44,773] p163 {161412846.py:14} INFO - ------ model=anthropic.claude-3-sonnet-20240229-v1:0 completed in 7.126633583000512 ------
# (async_get_inference pid=195) 17:14:44 - LiteLLM:INFO: utils.py:2911 - Wrapper: Completed Call, calling success_handler
# (async_get_inference pid=195) [2024-06-01 17:14:44,770] p195 {utils.py:2911} INFO - Wrapper: Completed Call, calling success_handler
# (async_get_inference pid=195) [2024-06-01 17:14:44,770] p195 {2625041246.py:49} INFO - completion: {
# (async_get_inference pid=195)   "best_match_title": "Probing Fundamental Physics",
# (async_get_inference pid=195)   "selected_model": "anthropic.claude-3-sonnet-20240229-v1:0",
# (async_get_inference pid=195)   "explanation": "The title 'Probing Fundamental Physics' generated by the anthropic.claude-3-sonnet-20240229-v1:0 model best captures the essence of the discussion, which revolves around exploring the fundamental nature of reality and physics through experiments and theoretical work. The other titles like 'Exploring the Frontiers of Reality' (amazon.titan-text-express-v1), 'Probing Particle Physics Frontiers' (anthropic.claude-3-haiku-20240307-v1:0), and 'Probing Reality's Fabric' (meta.llama3-70b-instruct-v1:0) also convey similar ideas but are not as concise and specific as 'Probing Fundamental Physics'. Titles like 'Particle Accelerators' (meta.llama3-8b-instruct-v1:0), 'New Insights' (mistral.mistral-7b-instruct-v0:2), and 'Exploring Reality' (mistral.mixtral-8x7b-instruct-v0:1) are too broad or focus on only one aspect of the discussion. The title 'The Role of Theory and Experimentation in Physics' (model_x) is accurate but too long and wordy compared to the selected title."
# (async_get_inference pid=195) }
# (async_get_inference pid=195) [2024-06-01 17:14:44,770] p195 {3857863317.py:15} INFO - The price for 724 tokens for anthropic.claude-3-sonnet-20240229-v1:0 for filename=particle_physics_meeting.json chapter=4 is 0.002172
# (async_get_inference pid=195) [2024-06-01 17:14:44,770] p195 {3857863317.py:17} INFO - The price for 354 tokens for anthropic.claude-3-sonnet-20240229-v1:0 for filename=particle_physics_meeting.json chapter=4 is 0.00531
# (async_get_inference pid=195) [2024-06-01 17:14:44,770] p195 {3857863317.py:21} INFO - writing response={'exception': None, 'prompt': 'Human: here is a transcript from a meeting in the <chapter></chapter> tag followed by chapter titles generated by different models.\nYour task is to select the title that best captures the content and meaning of the chapter in 1 to 4 words.\nPut the selected title, model name and explanation for selecting the title and not selecting other titles in a JSON as within 3 elements: "best_match_title", "selected_model", and "explanation".\nYour explanation should include both model name and title so that it is simple to understand which title was generated by which model and why it was or was not selected.\n\n<chapter>\n1011 "Dr. E" (1234567890)\n10:03:44.900 --> 10:03:51.200\nNot necessarily. With the advent of more powerful particle accelerators, we may be able to probe deeper into the fabric of reality.\n\n1012 "Dr. M" (2345678901)\n10:03:51.200 --> 10:03:57.500\nYou raise a fair point. The upcoming upgrades to the Large Hadron Collider could potentially reveal new insights.\n\n1013 "Dr. S" (3456789012)\n10:03:57.500 --> 10:04:03.800\nAnd let\'s not forget the importance of theoretical work. Sometimes the math leads us to unexpected places.\n\n1014 "Dr. D" (4567890123)\n10:04:03.800 --> 10:04:10.100\nAbsolutely. Some of the greatest breakthroughs in physics have come from pure thought experiments and mathematical models.\n</chapter>\n\n<model_x>\nThe Role of Theory and Experimentation in Physics\n</model_x>\n\n\n<amazon.titan-text-express-v1>\nExploring the Frontiers of Reality\n</amazon.titan-text-express-v1>\n\n\n<anthropic.claude-3-haiku-20240307-v1:0>\nProbing Particle Physics Frontiers\n</anthropic.claude-3-haiku-20240307-v1:0>\n\n\n<anthropic.claude-3-sonnet-20240229-v1:0>\nProbing Fundamental Physics\n</anthropic.claude-3-sonnet-20240229-v1:0>\n\n\n<meta.llama3-70b-instruct-v1:0>\nProbing Reality\'s Fabric\n</meta.llama3-70b-instruct-v1:0>\n\n\n<meta.llama3-8b-instruct-v1:0>\nParticle Accelerators\n</meta.llama3-8b-instruct-v1:0>\n\n\n<mistral.mistral-7b-instruct-v0:2>\nNew Insights\n</mistral.mistral-7b-instruct-v0:2>\n\n\n<mistral.mixtral-8x7b-instruct-v0:1>\nExploring Reality\n</mistral.mixtral-8x7b-instruct-v0:1>\n\n\nAssistant: Here is the response in json:\n', 'completion': '{\n  "best_match_title": "Probing Fundamental Physics",\n  "selected_model": "anthropic.claude-3-sonnet-20240229-v1:0",\n  "explanation": "The title \'Probing Fundamental Physics\' generated by the anthropic.claude-3-sonnet-20240229-v1:0 model best captures the essence of the discussion, which revolves around exploring the fundamental nature of reality and physics through experiments and theoretical work. The other titles like \'Exploring the Frontiers of Reality\' (amazon.titan-text-express-v1), \'Probing Particle Physics Frontiers\' (anthropic.claude-3-haiku-20240307-v1:0), and \'Probing Reality\'s Fabric\' (meta.llama3-70b-instruct-v1:0) also convey similar ideas but are not as concise and specific as \'Probing Fundamental Physics\'. Titles like \'Particle Accelerators\' (meta.llama3-8b-instruct-v1:0), \'New Insights\' (mistral.mistral-7b-instruct-v0:2), and \'Exploring Reality\' (mistral.mixtral-8x7b-instruct-v0:1) are too broad or focus on only one aspect of the discussion. The title \'The Role of Theory and Experimentation in Physics\' (model_x) is accurate but too long and wordy compared to the selected title."\n}', 'file_name': 'particle_physics_meeting.json', 'original_title': 'The Role of Theory and Experimentation in Physics', 'completion_token_count': 354, 'prompt_token_count': 724, 'input_token_price': 0.002172, 'output_token_pricing': 0.00531, 'model_id': 'anthropic.claude-3-sonnet-20240229-v1:0'} to data/model_eval_completions/particle_physics_meeting.json/anthropic.claude-3-sonnet-20240229-v1-0/model_evaluation_4.json
# (async_get_inference pid=195) [2024-06-01 17:14:44,771] p195 {3857863317.py:23} INFO - response 5: {'exception': None, 'prompt': 'Human: here is a transcript from a meeting in the <chapter></chapter> tag followed by chapter titles generated by different models.\nYour task is to select the title that best captures the content and meaning of the chapter in 1 to 4 words.\nPut the selected title, model name and explanation for selecting the title and not selecting other titles in a JSON as within 3 elements: "best_match_title", "selected_model", and "explanation".\nYour explanation should include both model name and title so that it is simple to understand which title was generated by which model and why it was or was not selected.\n\n<chapter>\n1011 "Dr. E" (1234567890)\n10:03:44.900 --> 10:03:51.200\nNot necessarily. With the advent of more powerful particle accelerators, we may be able to probe deeper into the fabric of reality.\n\n1012 "Dr. M" (2345678901)\n10:03:51.200 --> 10:03:57.500\nYou raise a fair point. The upcoming upgrades to the Large Hadron Collider could potentially reveal new insights.\n\n1013 "Dr. S" (3456789012)\n10:03:57.500 --> 10:04:03.800\nAnd let\'s not forget the importance of theoretical work. Sometimes the math leads us to unexpected places.\n\n1014 "Dr. D" (4567890123)\n10:04:03.800 --> 10:04:10.100\nAbsolutely. Some of the greatest breakthroughs in physics have come from pure thought experiments and mathematical models.\n</chapter>\n\n<model_x>\nThe Role of Theory and Experimentation in Physics\n</model_x>\n\n\n<amazon.titan-text-express-v1>\nExploring the Frontiers of Reality\n</amazon.titan-text-express-v1>\n\n\n<anthropic.claude-3-haiku-20240307-v1:0>\nProbing Particle Physics Frontiers\n</anthropic.claude-3-haiku-20240307-v1:0>\n\n\n<anthropic.claude-3-sonnet-20240229-v1:0>\nProbing Fundamental Physics\n</anthropic.claude-3-sonnet-20240229-v1:0>\n\n\n<meta.llama3-70b-instruct-v1:0>\nProbing Reality\'s Fabric\n</meta.llama3-70b-instruct-v1:0>\n\n\n<meta.llama3-8b-instruct-v1:0>\nParticle Accelerators\n</meta.llama3-8b-instruct-v1:0>\n\n\n<mistral.mistral-7b-instruct-v0:2>\nNew Insights\n</mistral.mistral-7b-instruct-v0:2>\n\n\n<mistral.mixtral-8x7b-instruct-v0:1>\nExploring Reality\n</mistral.mixtral-8x7b-instruct-v0:1>\n\n\nAssistant: Here is the response in json:\n', 'completion': '{\n  "best_match_title": "Probing Fundamental Physics",\n  "selected_model": "anthropic.claude-3-sonnet-20240229-v1:0",\n  "explanation": "The title \'Probing Fundamental Physics\' generated by the anthropic.claude-3-sonnet-20240229-v1:0 model best captures the essence of the discussion, which revolves around exploring the fundamental nature of reality and physics through experiments and theoretical work. The other titles like \'Exploring the Frontiers of Reality\' (amazon.titan-text-express-v1), \'Probing Particle Physics Frontiers\' (anthropic.claude-3-haiku-20240307-v1:0), and \'Probing Reality\'s Fabric\' (meta.llama3-70b-instruct-v1:0) also convey similar ideas but are not as concise and specific as \'Probing Fundamental Physics\'. Titles like \'Particle Accelerators\' (meta.llama3-8b-instruct-v1:0), \'New Insights\' (mistral.mistral-7b-instruct-v0:2), and \'Exploring Reality\' (mistral.mixtral-8x7b-instruct-v0:1) are too broad or focus on only one aspect of the discussion. The title \'The Role of Theory and Experimentation in Physics\' (model_x) is accurate but too long and wordy compared to the selected title."\n}', 'file_name': 'particle_physics_meeting.json', 'original_title': 'The Role of Theory and Experimentation in Physics', 'completion_token_count': 354, 'prompt_token_count': 724, 'input_token_price': 0.002172, 'output_token_pricing': 0.00531, 'model_id': 'anthropic.claude-3-sonnet-20240229-v1:0'}

# %% [markdown]
# #### Extract all evaluations from the model evaluator

# %%
## Represents extracted all metric files
fpath_evaluated_files = os.path.join(config['dir']['model_eval_completions'], "**", "*", "*.json")
eval_metric_files = glob.glob(fpath_evaluated_files, recursive=True)
logger.info(f"there are {len(eval_metric_files)} evaluated files by {config['eval_model_info']['model']} LLM judge in {fpath_evaluated_files}")
# Out:
# [2024-06-01 17:14:44,786] p163 {1986411679.py:4} INFO - there are 6 evaluated files by anthropic.claude-3-sonnet-20240229-v1:0 LLM judge in data/model_eval_completions/**/*/*.json

# %%
model_evaluation_responses = []
for f in eval_metric_files:
    with open(f, 'r') as file:
        model_evaluation_responses.append(json.loads(file.read()))
# results_df will contain the evaluation responses, including the completion and the model id
results_df = pd.DataFrame(model_evaluation_responses)
results_df = results_df.drop(columns=['exception', 'prompt', 'file_name'])
results_df.head(10)
# Out:
#                                           completion  \
# 0  {\n  "best_match_title": "Dimensions Beyond Sp...
# 1  {\n  "best_match_title": "Quantum Gravity Disc...
# 2  {\n  "best_match_title": "Antimatter Applicati...
# 3  {\n  "best_match_title": "Probing Fundamental ...
# 4  {\n  "best_match_title": "Future of Particle P...
# 5  {\n  "best_match_title": "Higgs Boson Discussi...
#
#                                       original_title  completion_token_count  \
# 0  Exploring Higher Dimensions and the Fabric of ...                     182
# 1          The Quest for a Theory of Quantum Gravity                     232
# 2          Antimatter and Its Potential Applications                     250
# 3  The Role of Theory and Experimentation in Physics                     354
# 4     Exploring Future Frontiers in Particle Physics                     316
# 5    Discussing the Higgs Boson and Its Implications                     214
#
#    prompt_token_count  input_token_price  output_token_pricing  \
# 0                 754           0.002262               0.00273
# 1                 773           0.002319               0.00348
# 2                 717           0.002151               0.00375
# 3                 724           0.002172               0.00531
# 4                 752           0.002256               0.00474
# 5                 790           0.002370               0.00321
#
#                                   model_id
# 0  anthropic.claude-3-sonnet-20240229-v1:0
# 1  anthropic.claude-3-sonnet-20240229-v1:0
# 2  anthropic.claude-3-sonnet-20240229-v1:0
# 3  anthropic.claude-3-sonnet-20240229-v1:0
# 4  anthropic.claude-3-sonnet-20240229-v1:0
# 5  anthropic.claude-3-sonnet-20240229-v1:0

# %%
def clean_model_eval_json(data):
    """
    This function is to take in json data, and clean it, assign the selected title as outputted by the model evaluator
    """
    try:
        json_data = json.loads(data.replace('\\', '\\\\'))
        return pd.Series({
            'best_match_title': json_data['best_match_title'],
            'selected_model': json_data['selected_model'],
            'explanation': json_data['explanation'],
        })
    except json.JSONDecodeError:
        return pd.Series({
            'best_match_title': None,
            'selected_model': None,
            'explanation': None,
        })

# %%
def tidy_split(df, column, sep=',', keep=False):
    """
    Split the values of a column and expand so the new DataFrame has one split
    value per row. Filters rows where the column is missing.
    
    Params
    ------
    df : pandas.DataFrame
        dataframe with the column to split and expand
    column : str
        the column to split and expand
    sep : str
        the string used to split the column's values
    keep : bool
        whether to retain the presplit value as it's own row

    Returns
    -------
    pandas.DataFrame
        Returns a dataframe with the same columns as `df`.
    """
    indexes = list()
    new_values = list()
    df = df.dropna(subset=[column])
    for i, presplit in enumerate(df[column].astype(str)):
        values = presplit.split(sep)
        if keep and len(values) > 1:
            indexes.append(i)
            new_values.append(presplit)
        for value in values:
            indexes.append(i)
            new_values.append(value)
    new_df = df.iloc[indexes, :].copy()
    new_df[column] = new_values
    return new_df

# %%
new_results_df = results_df['completion'].apply(clean_model_eval_json)
# removing any unnecessary characters from the selected_model if any
new_results_df['selected_model'] = new_results_df['selected_model'].str.replace(r'<[^>]+>', '', regex=True)
# here we split the elements of the selected_model column using the tidy split function
new_exploded_df = tidy_split(new_results_df, 'selected_model', sep=',')
new_results_df['chapter_title'] = results_df['original_title']
new_results_df['input_token_price'] = results_df['input_token_price']
new_results_df['output_token_price'] = results_df['output_token_pricing']
new_results_df = new_results_df.reindex(columns=['chapter_title', 'best_match_title', 'selected_model', 'explanation', 'input_token_price', 'output_token_price'])
logger.info(f"All evaluation data is read into a dataframe of shape {results_df.shape}")
processed_prompts_for_eval_path = os.path.join(metrics_dir, config['dir']['filtered_titles_for_eval'])
new_results_df.to_csv(processed_prompts_for_eval_path, index=False)
# display the selected title, model explanation and the respective golden title in a side by side view
new_results_df.head(10)
# Out:
# [2024-06-01 17:14:44,832] p163 {3809385060.py:10} INFO - All evaluation data is read into a dataframe of shape (6, 7)
#                                        chapter_title  \
# 0  Exploring Higher Dimensions and the Fabric of ...
# 1          The Quest for a Theory of Quantum Gravity
# 2          Antimatter and Its Potential Applications
# 3  The Role of Theory and Experimentation in Physics
# 4     Exploring Future Frontiers in Particle Physics
# 5    Discussing the Higgs Boson and Its Implications
#
#                best_match_title  \
# 0  Dimensions Beyond Space-Time
# 1    Quantum Gravity Discussion
# 2       Antimatter Applications
# 3   Probing Fundamental Physics
# 4    Future of Particle Physics
# 5        Higgs Boson Discussion
#
#                                       selected_model  \
# 0            anthropic.claude-3-sonnet-20240229-v1:0
# 1            anthropic.claude-3-sonnet-20240229-v1:0
# 2  anthropic.claude-3-sonnet-20240229-v1:0, meta....
# 3            anthropic.claude-3-sonnet-20240229-v1:0
# 4            anthropic.claude-3-sonnet-20240229-v1:0
# 5            anthropic.claude-3-sonnet-20240229-v1:0
#
#                                          explanation  input_token_price  \
# 0  The title 'Dimensions Beyond Space-Time' gener...           0.002262
# 1  The title 'Quantum Gravity Discussion' generat...           0.002319
# 2  The title 'Antimatter Applications' best captu...           0.002151
# 3  The title 'Probing Fundamental Physics' genera...           0.002172
# 4  The title 'Future of Particle Physics' generat...           0.002256
# 5  The title 'Higgs Boson Discussion' generated b...           0.002370
#
#    output_token_price
# 0             0.00273
# 1             0.00348
# 2             0.00375
# 3             0.00531
# 4             0.00474
# 5             0.00321

# %%
# Compute the percentage of each model selection and reset the index
new_exploded_df['selected_model'] = new_exploded_df['selected_model'].map(lambda x: x.strip())
model_percentage_df = new_exploded_df['selected_model'].value_counts(normalize=True).reset_index()
model_percentage_df['proportion'] *= 100
model_distribution_fpath = os.path.join(metrics_dir, config['dir']['model_distribution'])
model_percentage_df.to_csv(model_distribution_fpath, index=False)
model_percentage_df.rename(columns = {'selected_model':'model_id'}, inplace = True)
model_percentage_df.head(10)
# Out:
#                                   model_id  proportion
# 0  anthropic.claude-3-sonnet-20240229-v1:0        60.0
# 1            meta.llama3-70b-instruct-v1:0        10.0
# 2             meta.llama3-8b-instruct-v1:0        10.0
# 3         mistral.mistral-7b-instruct-v0:2        10.0
# 4       mistral.mixtral-8x7b-instruct-v0:1        10.0

# %%
# Identify the most frequently selected model
most_selected_index = model_percentage_df.proportion.idxmax()
report_template: str = config['report']['model_recommendation']
report: str = report_template.format(
                count=new_results_df.best_match_title.count(),
                model_id=model_percentage_df.iloc[most_selected_index]['model_id'],
                percentage_of_occurrence=model_percentage_df.proportion.max(), 
                total_evaluation_cost=round((new_results_df.input_token_price.sum() + new_results_df.output_token_price.sum()), 4))
result_data = {'model_recommendation': [report]}
results_summary_df = pd.DataFrame(result_data)
recommended_model_fpath = os.path.join(metrics_dir, config['dir']['final_report'])
# Saving to CSV
results_summary_df.to_csv(recommended_model_fpath, index=False)
print(report)
# Out:
# The recommended model with the best match title based on an evaluation of 6 titles is anthropic.claude-3-sonnet-20240229-v1:0, with a 60.0% selection rate. The total cost to run the LLM as a judge evaluation is $0.0368.

# %%
merged_df = pd.merge(df_summary, model_percentage_df, on='model_id', how='left')
merged_df.rename(columns={'proportion': 'LLM_as_a_judge_pick_rate'}, inplace=True)
merged_df['LLM_as_a_judge_pick_rate'] = merged_df['LLM_as_a_judge_pick_rate'].fillna("not available")
eval_report_template = config['report']['eval_report_explanation']

# Calculate the evaluation report for each row for the mean cosine, rouge and llm as a judge pick rate
merged_df['eval_report'] = merged_df.apply(lambda row: eval_report_template.format(
    rouge_score=row['mean_rouge_l_f1_score'],
    cosine_score=row['mean_cosine_similarity'],
    llm_as_a_judge=row['LLM_as_a_judge_pick_rate']
), axis=1)
merged_df = merged_df.loc[:, ~merged_df.columns.duplicated()]
cols = merged_df.columns.tolist()
idx = cols.index('mean_cosine_similarity')
cols.insert(idx + 1, cols.pop(cols.index('LLM_as_a_judge_pick_rate')))
cols.insert(idx + 2, cols.pop(cols.index('eval_report')))
merged_df = merged_df[cols]
merged_df.to_csv(summary_metrics_file_path, index=False)
merged_df
# Out:
#                                   model_id  latency_seconds  \
# 0  anthropic.claude-3-sonnet-20240229-v1:0         1.122653
# 1   anthropic.claude-3-haiku-20240307-v1:0         0.762285
# 2       mistral.mixtral-8x7b-instruct-v0:1         0.675825
# 3             meta.llama3-8b-instruct-v1:0         0.754584
# 4            meta.llama3-70b-instruct-v1:0         0.964386
# 5             amazon.titan-text-express-v1         1.126562
# 6         mistral.mistral-7b-instruct-v0:2         0.984149
# 7                  meta.llama2-13b-chat-v1         1.293597
#
#    completion_token_count  prompt_token_count  input_token_price  \
# 0                      13                 441           0.001324
# 1                      14                 441           0.000110
# 2                       5                 339           0.000153
# 3                       6                 347           0.000139
# 4                       7                 347           0.000920
# 5                       7                 385           0.000309
# 6                      35                 401           0.000060
# 7                      15                 488           0.000366
#
#    output_token_pricing  mean_rouge_l_f1_score  mean_cosine_similarity  \
# 0              0.000202               0.380583                0.788797
# 1              0.000018               0.297117                0.765014
# 2              0.000004               0.389167                0.761117
# 3              0.000004               0.389167                0.753589
# 4              0.000024               0.396567                0.750383
# 5              0.000012               0.452100                0.720899
# 6              0.000007               0.327533                0.631595
# 7              0.000016                    NaN                     NaN
#
#   LLM_as_a_judge_pick_rate                                        eval_report  \
# 0                     60.0  The mean ROUGE-L score is 0.380583, mean Cosin...
# 1            not available  The mean ROUGE-L score is 0.297117, mean Cosin...
# 2                     10.0  The mean ROUGE-L score is 0.389167, mean Cosin...
# 3                     10.0  The mean ROUGE-L score is 0.389167, mean Cosin...
# 4                     10.0  The mean ROUGE-L score is 0.396567, mean Cosin...
# 5            not available  The mean ROUGE-L score is 0.4521, mean Cosine ...
# 6                     10.0  The mean ROUGE-L score is 0.327533, mean Cosin...
# 7            not available  The mean ROUGE-L score is nan, mean Cosine Sim...
#
#    p95_latency_seconds  avg_cost_per_txn  p95_cost_per_txn  \
# 0             1.814916          0.001526          0.002480
# 1             0.962902          0.000129          0.000205
# 2             0.736683          0.000157          0.000166
# 3             0.766312          0.000143          0.000151
# 4             1.114516          0.000944          0.001002
# 5             1.299742          0.000321          0.000508
# 6             1.887510          0.000067          0.000113
# 7             1.694030          0.000382          0.000499
#
#    p95_completion_token_count  p95_prompt_token_count  count  \
# 0                       24.55                  703.85     10
# 1                       23.10                  703.85     10
# 2                        6.75                  358.50      6
# 3                        7.75                  366.50      6
# 4                        8.75                  366.50      6
# 5                       11.65                  611.90     10
# 6                       95.50                  627.90     10
# 7                       25.75                  631.30      4
#
#                                       overall_report
# 0  The average inference latency for this workloa...
# 1  The average inference latency for this workloa...
# 2  The average inference latency for this workloa...
# 3  The average inference latency for this workloa...
# 4  The average inference latency for this workloa...
# 5  The average inference latency for this workloa...
# 6  The average inference latency for this workloa...
# 7  The average inference latency for this workloa...

# %%
merged_relevant = merged_df[['model_id', 'LLM_as_a_judge_pick_rate', 'mean_cosine_similarity', 'mean_rouge_l_f1_score']]

new_results_df = new_results_df.rename(columns={'selected_model': 'model_id'})

# Merging new_results_df with the relevant columns from merged_df
result_df = pd.merge(new_results_df, merged_relevant, on='model_id', how='left')

# Renaming the 'model_id' column back to 'selected_model'
result_df = result_df.rename(columns={'model_id': 'selected_model'})

# Display the first 10 rows of the resulting DataFrame
result_df.head(10)

# %% [markdown]
# ### Compute the Recommended LLM based on a combined score of `Subjective` and `Quantitative` evaluation using `LLM as a judge`, `ROUGE` and `Cosine Similarity` metrics

# %%
# Fill NaN values with 0 in the normalized pick rate
merged_df['LLM_as_a_judge_pick_rate'].fillna(0, inplace=True)
merged_df['LLM_as_a_judge_pick_rate'] = merged_df['LLM_as_a_judge_pick_rate'] / 100
merged_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expressions.py:131, in _evaluate_numexpr(op, op_str, a, b)
#     130 if result is None:
# --> 131     result = _evaluate_standard(op, op_str, a, b)
#     133 return result
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 3
#       1 # Fill NaN values with 0 in the normalized pick rate
#       2 # merged_df['LLM_as_a_judge_pick_rate'].fillna(0, inplace=True)
# ----> 3 merged_df['LLM_as_a_judge_pick_rate'] = merged_df['LLM_as_a_judge_pick_rate'] / 100
#       4 merged_df
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/arraylike.py:210, in OpsMixin.__truediv__(self, other)
#     208 @unpack_zerodim_and_defer("__truediv__")
#     209 def __truediv__(self, other):
# --> 210     return self._arith_method(other, operator.truediv)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:6135, in Series._arith_method(self, other, op)
#    6133 def _arith_method(self, other, op):
#    6134     self, other = self._align_for_op(other)
# -> 6135     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/base.py:1382, in IndexOpsMixin._arith_method(self, other, op)
#    1379     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1381 with np.errstate(all="ignore"):
# -> 1382     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1384 return self._construct_result(result, name=res_name)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:283, in arithmetic_op(left, right, op)
#     279     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     281     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     282     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 283     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     285 return res_values
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:227, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 except TypeError:
#     220     if not is_cmp and (
#     221         left.dtype == object or getattr(right, "dtype", None) == object
#     222     ):
#    (...)
#     225         # Don't do this for comparisons, as that will handle complex numbers
#     226         #  incorrectly, see GH#32047
# --> 227         result = _masked_arith_op(left, right, op)
#     228     else:
#     229         raise
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:182, in _masked_arith_op(x, y, op)
#     179         mask = np.where(y == 1, False, mask)
#     181     if mask.any():
# --> 182         result[mask] = op(xrav[mask], y)
#     184 np.putmask(result, ~mask, np.nan)
#     185 result = result.reshape(x.shape)  # 2D compat
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
best_llm_judge_model = merged_df.sort_values(by='LLM_as_a_judge_pick_rate', ascending=False).iloc[0]['model_id']
best_llm_judge_model
# Out:
# 'anthropic.claude-3-sonnet-20240229-v1:0'

# %%
best_rouge_score_model = merged_df.sort_values(by='mean_rouge_l_f1_score', ascending=False).iloc[0]['model_id']
best_rouge_score_model
# Out:
# 'amazon.titan-text-express-v1'

# %%
best_cosine_model = merged_df.sort_values(by='mean_cosine_similarity', ascending=False).iloc[0]['model_id']
best_cosine_model
# Out:
# 'anthropic.claude-3-sonnet-20240229-v1:0'

# %%
best_llm_judge_model_value = merged_df.sort_values(by='LLM_as_a_judge_pick_rate', ascending=False).iloc[0]['LLM_as_a_judge_pick_rate']
best_llm_judge_model_value
# Out:
# 0.6

# %%
def recommend_model(df) -> str:
    """
    This function computes the recommended model based on the three evaluation criteria.
    If a model has the highest score for all three criteria, then it becomes the best model agreed by all three.
    If not, then it is checked for the combination of the rest of the two criteria. If none of the cases satisfy,
    then a best recommended model is returned for each of the evaluation criteria.
    """
    try: 
        evaluation_report: Optional[str] = None
        # model with the highest score using LLM as a judge eval
        best_llm_judge_model = df.sort_values(by='LLM_as_a_judge_pick_rate', ascending=False).iloc[0]['model_id']
        best_llm_judge_model_value = df.sort_values(by='LLM_as_a_judge_pick_rate', ascending=False).iloc[0]['LLM_as_a_judge_pick_rate']
        # model with the highest score using the ROUGE f1 score
        best_rouge_score_model = df.sort_values(by='mean_rouge_l_f1_score', ascending=False).iloc[0]['model_id']
        best_rouge_score_model_value = df.sort_values(by='mean_rouge_l_f1_score', ascending=False).iloc[0]['mean_rouge_l_f1_score']
        # model with the highest score using the Cosine Similarity score
        best_cosine_model = df.sort_values(by='mean_cosine_similarity', ascending=False).iloc[0]['model_id']
        best_cosine_model_value = df.sort_values(by='mean_cosine_similarity', ascending=False).iloc[0]['mean_cosine_similarity']

        # check if all three models that are selected on the three criteria are the same
        if best_llm_judge_model == best_rouge_score_model == best_cosine_model:
            evaluation_report = (
                f"As per all three evaluation criteria, '{best_llm_judge_model}' is the best recommended model for your workload "
                f"based on the LLM as a judge pick rate of {best_llm_judge_model_value*100}%, Cosine Similarity of {best_cosine_model_value} and ROUGE score of {best_rouge_score_model_value}."
            )
        # Check combinations of any two criteria permutations
        elif best_llm_judge_model == best_rouge_score_model:
            evaluation_report = (
                f"As per the two evaluation criteria, '{best_llm_judge_model}' is the best recommended model for your workload "
                f"based on the LLM as a judge pick rate of {best_llm_judge_model_value*100}%, and ROUGE score of {best_rouge_score_model_value}."
            )
        elif best_llm_judge_model == best_cosine_model:
            evaluation_report = (
                f"As per the two evaluation criteria, '{best_llm_judge_model}' is the best recommended model for your workload "
                f"based on the LLM as a judge pick rate of {best_llm_judge_model_value*100}%, and Cosine Similarity score of {best_cosine_model_value}."
            )
        elif best_rouge_score_model == best_cosine_model:
            evaluation_report = (
                f"As per the two evaluation criteria, '{best_rouge_score_model}' is the best recommended model for your workload "
                f"based on the Cosine Similarity of {best_cosine_model_value} and ROUGE score of {best_rouge_score_model_value}."
            )
        # If none of the combinations match, recommend based on each individual criterion
        else:
            evaluation_report = (
                f"Based on each evaluation criteria, the following models are best recommended. "
                f"LLM as a judge selects {best_llm_judge_model} as the best recommended model. "
                f"Cosine Similarity score selects {best_cosine_model} as the best recommended model. "
                f"ROUGE score selects {best_rouge_score_model} as the best recommended model."
            )
    except Exception as e:
        logger.error(f"The best recommended model could not be provided: {e}")
        evaluation_report: Optional[str] = None
    return evaluation_report

# %%
# get the overall model recommendation based on the three evaluation criteria
recommendation = recommend_model(merged_df)
# Save the overall model evaluation recommendation to a csv
overall_eval_report_fpath: str = os.path.join(config['dir']['metrics'], config['dir']['overall_eval_report'])
overall_eval_data = {'overall_eval_recommendation': [recommendation]}
overall_eval_df = pd.DataFrame(overall_eval_data)
overall_eval_df.to_csv(overall_eval_report_fpath, index=False)
print(recommendation)
# Out:
# As per the two evaluation criteria, 'anthropic.claude-3-sonnet-20240229-v1:0' is the best recommended model for your workload based on the LLM as a judge pick rate of 60.0%, and Cosine Similarity score of 0.788797.
